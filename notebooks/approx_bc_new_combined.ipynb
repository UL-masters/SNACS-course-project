# %% [markdown]
# # Approximating Betweenness Centrality

# %% [markdown]
# This notebook contains three algorithms for approximating betweenness centrality using sampling:
#
# - random sampling algorithm
# - degree-based sampling algorithm with Inverse Probability Weighting (IPW) technique
# - degree-based sampling algorithm without IPW
#
# All the algorithms are applied to 6 datasets:
#
# | Dataset          | Type        | Nodes  | Edges  |
# |------------------|-------------|--------|--------|
# | CA-Astrophysics  | undirected  | 17903  | 197031 |
# | p2p-Gnutella     | directed    | 62561  | 147878 |
# | Email-ENRON      | directed    | 33696  | 361622 |
# | Facebook         | undirected  | 22470  | 171002 |
# | Twitter          | directed    | 81306  | 1768149|
# | Bio-HS-CX        | undirected, weighted | 4409 | 108816 |

# %%
import random
from collections import deque
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from time import perf_counter

# %% [markdown]
# ## Algorithm 1: Adaptive Random sampling

# %% [markdown]
# This algorithm is originally from the paper Approximating Betweenness Centrality (Bader et al.).
#
# We first compute the single-source dependency scores $δ_s(v)$ for vertices $v$ in G using the unweighted version of Brandes' algorithm:

# %%
def brandes_single_source_dependencies_unweighted(G, s):
    S = []
    P = {v: [] for v in G}
    sigma = dict.fromkeys(G, 0.0)
    dist  = dict.fromkeys(G, -1)

    sigma[s] = 1.0
    dist[s] = 0

    from collections import deque
    Q = deque([s])

    while Q:
        v = Q.popleft()
        S.append(v)
        for w in G[v]:
            if dist[w] < 0:
                dist[w] = dist[v] + 1
                Q.append(w)
            if dist[w] == dist[v] + 1:
                sigma[w] += sigma[v]
                P[w].append(v)

    delta = dict.fromkeys(G, 0.0)
    while S:
        w = S.pop()
        for v in P[w]:
            if sigma[w] != 0:
                delta[v] += (sigma[v] / sigma[w]) * (1 + delta[w])

    return delta

# %% [markdown]
# Then, we sample nodes at random and use the function above to compute the betweenness centrality for the sampled nodes, and from this, we can approximate the betweenness centrality.

# %%
def approx_bc_algorithm1_random(G, c=5.0, cutoff_factor=20, seed=0):
    rng = random.Random(seed)
    nodes = list(G.nodes())
    n = len(nodes)

    max_bfs = max(1, n // cutoff_factor)
    print(f"[approx] adaptive + cutoff: max {max_bfs} BFS runs (n/{cutoff_factor}), c={c}")

    S = {v: 0.0 for v in nodes}      
    k = {v: 0   for v in nodes}    
    done = {v: False for v in nodes} 
    remaining = n                 

    bfs_used = 0
    t0 = perf_counter()

    while bfs_used < max_bfs and remaining > 0:
        s = rng.choice(nodes)
        delta = brandes_single_source_dependencies_unweighted(G, s)
        bfs_used += 1

        for v in nodes:
            if done[v] or v == s:
                continue
            S[v] += delta[v]
            k[v] += 1
            if S[v] >= c * n:
                done[v] = True
                remaining -= 1

        if bfs_used % 10 == 0 or bfs_used == max_bfs:
            print(f"[approx] BFS {bfs_used}/{max_bfs}, remaining not-done vertices: {remaining}")

    t1 = perf_counter()
    print(f"[approx] finished in {t1 - t0:.2f}s, BFS_used={bfs_used}")

    bc_hat = {
        v: (n * S[v] / k[v]) if k[v] > 0 else 0.0
        for v in nodes
    }

    if not G.is_directed():
        for v in bc_hat:
            bc_hat[v] /= 2.0
            
    return bc_hat, k, bfs_used

# %%
# function to smooth figures (later on)
def smooth_series(y, window=51):
    w = max(3, int(window))
    if w % 2 == 0:
        w += 1
    if w > len(y):
        w = len(y) if len(y) % 2 == 1 else len(y) - 1
        if w < 3:
            return np.array(y, dtype=float)
    kernel = np.ones(w) / w
    ypad = np.pad(y, (w // 2, w // 2), mode='edge')
    return np.convolve(ypad, kernel, mode='valid')

# %% [markdown]
# ## Algorithm 2: Degree-based sampling with IPW

# %% [markdown]
# This algorithm is our own research. Our idea was to assess whether sampling nodes based on the highest degree (instead of at random) would show an improvement in the accuracy of the approximation of betweenness centrality.

# %%
def approx_bc_algorithm1_degree_based(G, c=5.0, cutoff_factor=20, alpha=1.0, seed=0):
    rng = random.Random(seed)
    nodes = list(G.nodes())
    n = len(nodes)

    # compute degree-based sampling probabilities
    degs = np.array([G.degree(v) for v in nodes], dtype=float)
    if alpha == 0:
        weights = np.ones(n, dtype=float)
    else:
        weights = np.power(degs, alpha)
        
    if np.all(weights == 0):
        probs = np.ones(n, dtype=float) / n
    else:
        probs = weights / weights.sum() # Normalize so sum is 1
        
    cum_probs = np.cumsum(probs)

    # For fast probability lookup, create a mapping (or access directly via index)
    # Since nodes is a list, for efficiency, we assume index correspondence
    
    def sample_source_and_prob():
        x = rng.random()
        idx = np.searchsorted(cum_probs, x, side="left")
        if idx >= n:
            idx = n - 1
        return nodes[idx], probs[idx]

    max_bfs = max(1, n // cutoff_factor)
    print(f"[approx-alpha-degree] max {max_bfs} BFS runs, c={c}, alpha={alpha}")

    S = {v: 0.0 for v in nodes}
    k = {v: 0   for v in nodes}
    done = {v: False for v in nodes}
    remaining = n
    bfs_used = 0
    t0 = perf_counter()

    while bfs_used < max_bfs and remaining > 0:
        # sample source according to degree-based probabilities
        s, p_s = sample_source_and_prob() 

        delta = brandes_single_source_dependencies_unweighted(G, s)
        bfs_used += 1

        # sample source according to degree-based probabilities
        # Principle: Uniform probability is 1/n, current probability is p_s. Scale factor is (1/n) / p_s
        scale_factor = 1.0 / (n * p_s) if p_s > 0 else 0

        for v in nodes:
            if done[v] or v == s:
                continue
            
            S[v] += delta[v] * scale_factor 
            k[v] += 1
            
            if S[v] >= c * n: 
                done[v] = True
                remaining -= 1

        if bfs_used % 10 == 0 or bfs_used == max_bfs:
             print(f"[approx-alpha-degree] BFS {bfs_used}/{max_bfs}, remaining={remaining}")

    t1 = perf_counter()
    print(f"[approx-alpha-degree] finished in {t1 - t0:.2f}s")

    bc_hat = {
        v: (n * S[v] / k[v]) if k[v] > 0 else 0.0
        for v in nodes
    }

    if not G.is_directed():
        for v in bc_hat:
            bc_hat[v] /= 2.0
            
    return bc_hat, k, bfs_used

# %% [markdown]
# ## Algorithm 3 degree-based sampling without IPW

# %%
def approx_bc_algorithm1_degree_based_no_ipw(G, c=5.0, cutoff_factor=20, alpha=1.0, seed=0):

    rng = random.Random(seed)
    nodes = list(G.nodes())
    n = len(nodes)

    # Compute sampling probabilities
    degs = np.array([G.degree(v) for v in nodes], dtype=float)
    if alpha == 0:
        weights = np.ones(n, dtype=float)
    else:
        weights = np.power(degs, alpha)
        
    if np.all(weights == 0):
        probs = np.ones(n, dtype=float) / n
    else:
        probs = weights / weights.sum()
        
    cum_probs = np.cumsum(probs)

    def sample_source():
        x = rng.random()
        idx = np.searchsorted(cum_probs, x, side="left")
        if idx >= n:
            idx = n - 1
        return nodes[idx]

    max_bfs = max(1, n // cutoff_factor)
    print(f"[approx-degree-NO-IPW] max {max_bfs} BFS runs, c={c}, alpha={alpha}")

    S = {v: 0.0 for v in nodes}
    k = {v: 0   for v in nodes}
    done = {v: False for v in nodes}
    remaining = n
    bfs_used = 0
    t0 = perf_counter()

    while bfs_used < max_bfs and remaining > 0:
        # 2. Sample source (biased towards hubs)
        s = sample_source()

        # 3. Compute dependencies
        delta = brandes_single_source_dependencies_unweighted(G, s)
        bfs_used += 1

        #  No scale_factor         
        for v in nodes:
            if done[v] or v == s:
                continue
            
            S[v] += delta[v] 
            k[v] += 1
            
            if S[v] >= c * n: 
                done[v] = True
                remaining -= 1

        if bfs_used % 10 == 0 or bfs_used == max_bfs:
             pass

    t1 = perf_counter()
    print(f"[approx-degree-NO-IPW] finished in {t1 - t0:.2f}s")

    bc_hat = {
        v: (n * S[v] / k[v]) if k[v] > 0 else 0.0
        for v in nodes
    }

    if not G.is_directed():
        for v in bc_hat:
            bc_hat[v] /= 2.0
            
    return bc_hat, k, bfs_used

# %% [markdown]
# ## Metrics
# Function to plot the BC distribtuion (exact, random-based, degree-based)

# %%
def plot_fig1_four_methods(exact_bc, approx_rand, approx_deg_ipw, approx_deg_no_ipw, title_suffix=""):
    # Rank vertices by exact BC
    nodes_sorted = sorted(exact_bc.keys(), key=lambda v: exact_bc[v])
    x = np.arange(len(nodes_sorted))

    #  Get y values
    y_exact   = np.array([exact_bc[v]       for v in nodes_sorted])
    y_rand    = np.array([approx_rand[v]    for v in nodes_sorted])
    y_deg_ipw = np.array([approx_deg_ipw[v] for v in nodes_sorted])
    y_deg_no  = np.array([approx_deg_no_ipw[v] for v in nodes_sorted])

    # Smooth series
    y_rand_smooth    = smooth_series(y_rand, window=max(31, len(y_rand)//50))
    y_deg_ipw_smooth = smooth_series(y_deg_ipw, window=max(31, len(y_deg_ipw)//50))
    y_deg_no_smooth  = smooth_series(y_deg_no,  window=max(31, len(y_deg_no)//50))

    #  Plot
    plt.figure(figsize=(8, 5))

    # Exact (Scatter)
    plt.scatter(x, y_exact, s=5, alpha=0.5, color='gray', label="Exact (Brandes)")

    # Approx Lines
    plt.plot(x, y_rand_smooth,    "r--", lw=1.5, label="Random (Adaptive)")
    plt.plot(x, y_deg_ipw_smooth, "g-.", lw=1.5, label="Degree (With IPW)")
    plt.plot(x, y_deg_no_smooth,  "b:",  lw=2.0, label="Degree (No IPW)")

    plt.yscale("log")
    plt.xlabel("Vertices (sorted by exact BC)")
    plt.ylabel("Betweenness Centrality")
    plt.title(f"{title_suffix} – BC Distribution Comparison")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Function to plot the approximation error across the top-30 vertices (random-based vs degree-based)

# %%
def plot_bc_error_three_methods(
    exact_bc,
    approx_rand,
    approx_deg_ipw,
    approx_deg_no_ipw,
    top_k=30,
    title=None
):
    # Top-k nodes by exact BC
    top_nodes = sorted(exact_bc, key=exact_bc.get, reverse=True)[:top_k]

    err_rand = []
    err_ipw  = []
    err_no   = []

    for v in top_nodes:
        exact_val = exact_bc[v]
        if exact_val == 0:
            err_rand.append(0.0)
            err_ipw.append(0.0)
            err_no.append(0.0)
            continue
            
        # Error formula: |approx - exact| / exact * 100
        err_rand.append(abs(approx_rand.get(v,0) - exact_val) / exact_val * 100)
        err_ipw.append(abs(approx_deg_ipw.get(v,0) - exact_val) / exact_val * 100)
        err_no.append(abs(approx_deg_no_ipw.get(v,0) - exact_val) / exact_val * 100)

    x = np.arange(1, top_k + 1)

    plt.figure(figsize=(10, 5))
    
    # Plot 3 lines
    plt.plot(x, err_rand, "o-", color="red",   label="Random", ms=4, alpha=0.8)
    plt.plot(x, err_ipw,  "s-", color="green", label="Degree (IPW)", ms=4, alpha=0.8)
    plt.plot(x, err_no,   "^-", color="blue",  label="Degree (No IPW)", ms=4, alpha=0.8)

    plt.xlabel("High-centrality vertices (Ranked by exact BC)")
    plt.ylabel("Relative Error (%)")
    
    # Customize x-ticks
    if top_k > 30:
        ticks = [1] + list(range(5, top_k + 1, 5))
        plt.xticks(ticks)
    else:
        plt.xticks(x)

    if title:
        plt.title(title)
    
    plt.legend()
    plt.grid(alpha=0.2)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Function to plot fig 3, the percentage of BFS/SSSP computations required for ap-
# proximating the centrality scores

# %%
def plot_bfs_percentages_three_methods(
    G,
    exact_bc,
    k_rand,
    k_deg_ipw,
    k_deg_no_ipw,
    top_k=30,
    title=None
):
    n = G.number_of_nodes()
    top_nodes = sorted(exact_bc, key=exact_bc.get, reverse=True)[:top_k]

    pct_rand = [100.0 * k_rand[v] / n for v in top_nodes]
    pct_ipw  = [100.0 * k_deg_ipw[v] / n for v in top_nodes]
    pct_no   = [100.0 * k_deg_no_ipw[v] / n for v in top_nodes]

    x = np.arange(1, top_k + 1)

    plt.figure(figsize=(10, 5))

    plt.plot(x, pct_rand, "o-", color="red",   label="Random", ms=4)
    plt.plot(x, pct_ipw,  "s-", color="green", label="Degree (IPW)", ms=4)
    plt.plot(x, pct_no,   "^-", color="blue",  label="Degree (No IPW)", ms=4)

    plt.xlabel("High-centrality vertices (Ranked by exact BC)")
    plt.ylabel("Samples Used (% of N)")
    
    # customize x-ticks
    if top_k > 30:
        ticks = [1] + list(range(5, top_k + 1, 5))
        plt.xticks(ticks)
    else:
        plt.xticks(x)

    if title:
        plt.title(title)

    plt.legend()
    plt.grid(alpha=0.2)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# function to compute top k ranking accuracy and correlation

# %%
from scipy.stats import spearmanr

def compute_top_k_overlap(exact_bc, approx_bc, k=50):
    top_exact = set(sorted(exact_bc, key=exact_bc.get, reverse=True)[:k])
    
    top_approx = set(sorted(approx_bc, key=approx_bc.get, reverse=True)[:k])
    
    overlap_count = len(top_exact.intersection(top_approx))
    
    return (overlap_count / k) * 100.0

# %% [markdown]
# Function for loading graph

# %%
def load_graph(
    path,
    directed: bool,
    use_giant_component: bool = True,
):
    """
    Load a graph from an edgelist file.

    Parameters
    ----------
    path : str
        Path to the edgelist file.
    directed : bool
        True -> DiGraph, False -> Graph.
    use_giant_component : bool
        If True, keep only the largest (weakly) connected component.

    Returns
    -------
    G : nx.Graph or nx.DiGraph
    """

    GraphClass = nx.DiGraph if directed else nx.Graph

    # read graph from edgelist
    G = nx.read_edgelist(
        path,
        comments="#",
        create_using=GraphClass(),
        nodetype=int,
    )
    print(f"[load] full graph from {path}: n={G.number_of_nodes()}, m={G.number_of_edges()}")

    # keep only the giant component
    if use_giant_component:
        if directed:
            is_conn = nx.is_weakly_connected(G)
            if not is_conn:
                gcc_nodes = max(nx.weakly_connected_components(G), key=len)
                G = G.subgraph(gcc_nodes).copy()
                print(f"[load] use giant WCC: n={G.number_of_nodes()}, m={G.number_of_edges()}")
        else:
            is_conn = nx.is_connected(G)
            if not is_conn:
                gcc_nodes = max(nx.connected_components(G), key=len)
                G = G.subgraph(gcc_nodes).copy()
                print(f"[load] use giant CC: n={G.number_of_nodes()}, m={G.number_of_edges()}")


    return G

# %%
def load_csv_edge_list(path, directed=True):
    GraphClass = nx.DiGraph if directed else nx.Graph

    with open(path, "r") as f:
        header = next(f)  
        G = nx.read_edgelist(
            f,                
            delimiter=",",
            create_using=GraphClass(),
            nodetype=int,
            data=False,
        )

    print(f"Facebook CSV graph: n={G.number_of_nodes()}, m={G.number_of_edges()}")
    return G

# %% [markdown]
# Function to compute error for top k nodes

# %%
def compute_top_k_error(exact_bc, approx_bc, k=30):
    # rank nodes by exact BC from high to low
    top_k_nodes = sorted(exact_bc.keys(), key=lambda v: exact_bc[v], reverse=True)[:k]
    
    errors = []
    for v in top_k_nodes:
        exact_val = exact_bc[v]
        approx_val = approx_bc.get(v, 0.0) # in case v not in approx_bc
        
        # avoid division by zero
        if exact_val > 0:
            err = abs(approx_val - exact_val) / exact_val
            errors.append(err)
            
    if not errors:
        return 0.0
        
    return np.mean(errors) * 100  # return percentage

# %% [markdown]
# ## Set parameters

# %%
c_val = 5
cutoff_factor = 20
top_k = 30
alpha = 1.0
seed = 42

# %% [markdown]
# # ==== Applying algorithms to the datasets ====

# %% [markdown]
# ## 1. CA-AstroPh (new) -> undirected
# https://snap.stanford.edu/data/ca-AstroPh.html

# %%
G_ca = load_graph("../data/real-world-new/CA-AstroPh_undirected.txt",
                       directed=False, use_giant_component=True)
n_ca = G_ca.number_of_nodes()
print("CA-AstroPh:", n_ca, G_ca.number_of_edges())
# Out:
# [load] full graph from ../data/real-world-new/CA-AstroPh_undirected.txt: n=18772, m=198110
# [load] use giant CC: n=17903, m=197031
# CA-AstroPh: 17903 197031

# %% [markdown]
# Random Sampling

# %%
# Approximate: one run, c=5, cutoff n/20 
approx_ca, k_used_ca, bfs_used_ca = approx_bc_algorithm1_random(
    G_ca,
    c=c_val,
    cutoff_factor=cutoff_factor,
    seed=seed,
)
print(f"[CA-AstroPh approx] BFS used = {bfs_used_ca}, "
      f"avg samples per node = {np.mean(list(k_used_ca.values())):.2f}")
# Out:
# [approx] adaptive + cutoff: max 895 BFS runs (n/20), c=5
# [approx] BFS 10/895, remaining not-done vertices: 17903
# [approx] BFS 20/895, remaining not-done vertices: 17903
# [approx] BFS 30/895, remaining not-done vertices: 17903
# [approx] BFS 40/895, remaining not-done vertices: 17903
# [approx] BFS 50/895, remaining not-done vertices: 17903
# [approx] BFS 60/895, remaining not-done vertices: 17903
# [approx] BFS 70/895, remaining not-done vertices: 17903
# [approx] BFS 80/895, remaining not-done vertices: 17903
# [approx] BFS 90/895, remaining not-done vertices: 17903
# [approx] BFS 100/895, remaining not-done vertices: 17903
# [approx] BFS 110/895, remaining not-done vertices: 17903
# [approx] BFS 120/895, remaining not-done vertices: 17903
# [approx] BFS 130/895, remaining not-done vertices: 17903
# [approx] BFS 140/895, remaining not-done vertices: 17903
# [approx] BFS 150/895, remaining not-done vertices: 17903
# [approx] BFS 160/895, remaining not-done vertices: 17903
# [approx] BFS 170/895, remaining not-done vertices: 17903
# [approx] BFS 180/895, remaining not-done vertices: 17903
# [approx] BFS 190/895, remaining not-done vertices: 17903
# [approx] BFS 200/895, remaining not-done vertices: 17903
# [approx] BFS 210/895, remaining not-done vertices: 17902
# [approx] BFS 220/895, remaining not-done vertices: 17902
# [approx] BFS 230/895, remaining not-done vertices: 17902
# [approx] BFS 240/895, remaining not-done vertices: 17902
# [approx] BFS 250/895, remaining not-done vertices: 17901
# [approx] BFS 260/895, remaining not-done vertices: 17901
# [approx] BFS 270/895, remaining not-done vertices: 17901
# [approx] BFS 280/895, remaining not-done vertices: 17901
# [approx] BFS 290/895, remaining not-done vertices: 17901
# [approx] BFS 300/895, remaining not-done vertices: 17901
# [approx] BFS 310/895, remaining not-done vertices: 17901
# [approx] BFS 320/895, remaining not-done vertices: 17901
# [approx] BFS 330/895, remaining not-done vertices: 17901
# [approx] BFS 340/895, remaining not-done vertices: 17901
# [approx] BFS 350/895, remaining not-done vertices: 17901
# [approx] BFS 360/895, remaining not-done vertices: 17901
# [approx] BFS 370/895, remaining not-done vertices: 17901
# [approx] BFS 380/895, remaining not-done vertices: 17901
# [approx] BFS 390/895, remaining not-done vertices: 17900
# [approx] BFS 400/895, remaining not-done vertices: 17899
# [approx] BFS 410/895, remaining not-done vertices: 17899
# [approx] BFS 420/895, remaining not-done vertices: 17898
# [approx] BFS 430/895, remaining not-done vertices: 17898
# [approx] BFS 440/895, remaining not-done vertices: 17898
# [approx] BFS 450/895, remaining not-done vertices: 17898
# [approx] BFS 460/895, remaining not-done vertices: 17898
# [approx] BFS 470/895, remaining not-done vertices: 17898
# [approx] BFS 480/895, remaining not-done vertices: 17897
# [approx] BFS 490/895, remaining not-done vertices: 17896
# [approx] BFS 500/895, remaining not-done vertices: 17895
# [approx] BFS 510/895, remaining not-done vertices: 17894
# [approx] BFS 520/895, remaining not-done vertices: 17894
# [approx] BFS 530/895, remaining not-done vertices: 17894
# [approx] BFS 540/895, remaining not-done vertices: 17893
# [approx] BFS 550/895, remaining not-done vertices: 17893
# [approx] BFS 560/895, remaining not-done vertices: 17892
# [approx] BFS 570/895, remaining not-done vertices: 17892
# [approx] BFS 580/895, remaining not-done vertices: 17891
# [approx] BFS 590/895, remaining not-done vertices: 17890
# [approx] BFS 600/895, remaining not-done vertices: 17890
# [approx] BFS 610/895, remaining not-done vertices: 17890
# [approx] BFS 620/895, remaining not-done vertices: 17890
# [approx] BFS 630/895, remaining not-done vertices: 17890
# [approx] BFS 640/895, remaining not-done vertices: 17889
# [approx] BFS 650/895, remaining not-done vertices: 17889
# [approx] BFS 660/895, remaining not-done vertices: 17888
# [approx] BFS 670/895, remaining not-done vertices: 17887
# [approx] BFS 680/895, remaining not-done vertices: 17885
# [approx] BFS 690/895, remaining not-done vertices: 17885
# [approx] BFS 700/895, remaining not-done vertices: 17884
# [approx] BFS 710/895, remaining not-done vertices: 17883
# [approx] BFS 720/895, remaining not-done vertices: 17881
# [approx] BFS 730/895, remaining not-done vertices: 17880
# [approx] BFS 740/895, remaining not-done vertices: 17879
# [approx] BFS 750/895, remaining not-done vertices: 17878
# [approx] BFS 760/895, remaining not-done vertices: 17878
# [approx] BFS 770/895, remaining not-done vertices: 17878
# [approx] BFS 780/895, remaining not-done vertices: 17878
# [approx] BFS 790/895, remaining not-done vertices: 17877
# [approx] BFS 800/895, remaining not-done vertices: 17877
# [approx] BFS 810/895, remaining not-done vertices: 17875
# [approx] BFS 820/895, remaining not-done vertices: 17875
# [approx] BFS 830/895, remaining not-done vertices: 17875
# [approx] BFS 840/895, remaining not-done vertices: 17875
# [approx] BFS 850/895, remaining not-done vertices: 17874
# [approx] BFS 860/895, remaining not-done vertices: 17874
# [approx] BFS 870/895, remaining not-done vertices: 17874
# [approx] BFS 880/895, remaining not-done vertices: 17873
# [approx] BFS 890/895, remaining not-done vertices: 17872
# [approx] BFS 895/895, remaining not-done vertices: 17871
# [approx] finished in 71.91s, BFS_used=895
# [CA-AstroPh approx] BFS used = 895, avg samples per node = 894.47

# %% [markdown]
# Degree-based sampling

# %%
approx_ca_deg, k_used_ca_deg, bfs_used_ca_deg = approx_bc_algorithm1_degree_based(
    G_ca,
    c=c_val,
    cutoff_factor=cutoff_factor,
    seed=seed,
)
print(f"[CA-AstroPh approx DEGREE] BFS used = {bfs_used_ca_deg}, "
      f"avg samples per node = {np.mean(list(k_used_ca_deg.values())):.2f}")
# Out:
# [approx-alpha-degree] max 895 BFS runs, c=5, alpha=1.0
# [approx-alpha-degree] BFS 10/895, remaining=17903
# [approx-alpha-degree] BFS 20/895, remaining=17903
# [approx-alpha-degree] BFS 30/895, remaining=17903
# [approx-alpha-degree] BFS 40/895, remaining=17902
# [approx-alpha-degree] BFS 50/895, remaining=17902
# [approx-alpha-degree] BFS 60/895, remaining=17902
# [approx-alpha-degree] BFS 70/895, remaining=17902
# [approx-alpha-degree] BFS 80/895, remaining=17902
# [approx-alpha-degree] BFS 90/895, remaining=17902
# [approx-alpha-degree] BFS 670/895, remaining=17864
# [approx-alpha-degree] BFS 680/895, remaining=17863
# [approx-alpha-degree] BFS 690/895, remaining=17863
# [approx-alpha-degree] BFS 700/895, remaining=17861
# [approx-alpha-degree] BFS 710/895, remaining=17861
# [approx-alpha-degree] BFS 720/895, remaining=17861
# [approx-alpha-degree] BFS 730/895, remaining=17861
# [approx-alpha-degree] BFS 740/895, remaining=17861
# [approx-alpha-degree] BFS 750/895, remaining=17861
# [approx-alpha-degree] BFS 760/895, remaining=17859
# [approx-alpha-degree] BFS 770/895, remaining=17859
# [approx-alpha-degree] BFS 780/895, remaining=17856
# [approx-alpha-degree] BFS 790/895, remaining=17855
# [approx-alpha-degree] BFS 800/895, remaining=17852
# [approx-alpha-degree] BFS 810/895, remaining=17851
# [approx-alpha-degree] BFS 820/895, remaining=17850
# [approx-alpha-degree] BFS 830/895, remaining=17850
# [approx-alpha-degree] BFS 840/895, remaining=17848
# [approx-alpha-degree] BFS 850/895, remaining=17846
# [approx-alpha-degree] BFS 860/895, remaining=17844
# [approx-alpha-degree] BFS 870/895, remaining=17843
# [approx-alpha-degree] BFS 880/895, remaining=17843
# [approx-alpha-degree] BFS 890/895, remaining=17841
# [approx-alpha-degree] BFS 895/895, remaining=17841
# [approx-alpha-degree] finished in 75.27s
# [CA-AstroPh approx DEGREE] BFS used = 895, avg samples per node = 893.71

# %% [markdown]
# degree-based sampling without IPW

# %%
approx_ca_deg_no, k_used_ca_deg_no, bfs_used_ca_deg_no = approx_bc_algorithm1_degree_based_no_ipw(
    G_ca, c=c_val, cutoff_factor=cutoff_factor, seed=seed, alpha=1.0
)
# Out:
# [approx-degree-NO-IPW] max 895 BFS runs, c=5, alpha=1.0
# [approx-degree-NO-IPW] finished in 75.00s

# %% [markdown]
# Exact (Brandes)

# %%
# Exact Brandes O(nm) 
t0 = perf_counter()
exact_ca = nx.betweenness_centrality(G_ca, normalized=False)
t1 = perf_counter()
print(f"[CA-AstroPh exact] finished in {t1 - t0:.2f}s")
# Out:
# [CA-AstroPh exact] finished in 1220.86s

# %% [markdown]
# Fig 1 BC distribution

# %%
plot_fig1_four_methods(
    exact_bc = exact_ca,
    approx_rand = approx_ca,
    approx_deg_ipw = approx_ca_deg,
    approx_deg_no_ipw = approx_ca_deg_no,
    title_suffix = "CA-AstroPh"
)

# %% [markdown]
# Fig 2 Approximate BC Error

# %%
plot_bc_error_three_methods(
    exact_bc = exact_ca,
    approx_rand = approx_ca,
    approx_deg_ipw = approx_ca_deg,
    approx_deg_no_ipw = approx_ca_deg_no,
    top_k = top_k,
    title = f"CA-AstroPh: Top-{top_k} Error Comparison"
)

# %% [markdown]
# Fig 3 Sampling Percentage

# %%
plot_bfs_percentages_three_methods(
    G_ca,
    exact_ca,
    k_rand = k_used_ca,
    k_deg_ipw = k_used_ca_deg,
    k_deg_no_ipw = k_used_ca_deg_no,
    top_k = top_k,
    title = f"CA-AstroPh: Sampling Efficiency"
)

# %% [markdown]
# Compute the average error on top-k nodes

# %%
avg_err_rand_ca = compute_top_k_error(exact_ca, approx_ca, k=top_k)
avg_err_ipw_ca  = compute_top_k_error(exact_ca, approx_ca_deg, k=top_k)
avg_err_no_ca   = compute_top_k_error(exact_ca, approx_ca_deg_no, k=top_k)


ov_rand_ca = compute_top_k_overlap(exact_ca, approx_ca, k=top_k)
ov_ipw_ca  = compute_top_k_overlap(exact_ca, approx_ca_deg, k=top_k)
ov_no_ca   = compute_top_k_overlap(exact_ca, approx_ca_deg_no, k=top_k)

print(f"{'Method':<25} | {'Average Error':<10} | {'Overlap %':<10}")
print("-" * 55)
print(f"{'Adaptive Random':<25} | {avg_err_rand_ca:6.2f}%    | {ov_rand_ca:6.2f}%")
print(f"{'Degree (With IPW)':<25} | {avg_err_ipw_ca:6.2f}%    | {ov_ipw_ca:6.2f}%")
print(f"{'Degree (No IPW)':<25} | {avg_err_no_ca:6.2f}%    | {ov_no_ca:6.2f}%")
print("-" * 55)
# Out:
# Method                    | Average Error | Overlap %
# -------------------------------------------------------
# Adaptive Random           |  11.36%    |  83.33%
# Degree (With IPW)         |  43.10%    |  40.00%
# Degree (No IPW)           |  15.12%    |  80.00%
# -------------------------------------------------------

# %% [markdown]
# ## 2. P2P dataset (new) -> directed

# %% [markdown]
# https://snap.stanford.edu/data/p2p-Gnutella31.html

# %%
p2p_path = "../data/real-world-new/p2p-Gnutella31_directed.txt"  
G_p2p = load_graph(p2p_path, directed=True, use_giant_component=True)
n_p2p = G_p2p.number_of_nodes()
print("P2P-Gnutella31:", n_p2p, G_p2p.number_of_edges())
# Out:
# [load] full graph from ../data/real-world-new/p2p-Gnutella31_directed.txt: n=62586, m=147892
# [load] use giant WCC: n=62561, m=147878
# P2P-Gnutella31: 62561 147878

# %% [markdown]
# Random sampling

# %%
approx_p2p, k_used_p2p, bfs_used_p2p = approx_bc_algorithm1_random(
    G_p2p,
    c=c_val,
    cutoff_factor=cutoff_factor,
    seed=seed,
)

print(
    f"[P2P-Gnutella31 approx] c={c_val}, cutoff=n/{cutoff_factor}, "
    f"BFS used = {bfs_used_p2p}, "
    f"avg samples per node = {np.mean(list(k_used_p2p.values())):.2f}"
)
# Out:
# [approx] adaptive + cutoff: max 3128 BFS runs (n/20), c=5
# [approx] BFS 10/3128, remaining not-done vertices: 62561
# [approx] BFS 20/3128, remaining not-done vertices: 62561
# [approx] BFS 30/3128, remaining not-done vertices: 62561
# [approx] BFS 40/3128, remaining not-done vertices: 62561
# [approx] BFS 50/3128, remaining not-done vertices: 62561
# [approx] BFS 60/3128, remaining not-done vertices: 62561
# [approx] BFS 70/3128, remaining not-done vertices: 62561
# [approx] BFS 80/3128, remaining not-done vertices: 62561
# [approx] BFS 90/3128, remaining not-done vertices: 62561
# [approx] BFS 100/3128, remaining not-done vertices: 62561
# [approx] BFS 110/3128, remaining not-done vertices: 62561
# [approx] BFS 120/3128, remaining not-done vertices: 62561
# [approx] BFS 130/3128, remaining not-done vertices: 62561
# [approx] BFS 140/3128, remaining not-done vertices: 62561
# [approx] BFS 2830/3128, remaining not-done vertices: 62549
# [approx] BFS 2840/3128, remaining not-done vertices: 62549
# [approx] BFS 2850/3128, remaining not-done vertices: 62549
# [approx] BFS 2860/3128, remaining not-done vertices: 62549
# [approx] BFS 2870/3128, remaining not-done vertices: 62549
# [approx] BFS 2880/3128, remaining not-done vertices: 62549
# [approx] BFS 2890/3128, remaining not-done vertices: 62549
# [approx] BFS 2900/3128, remaining not-done vertices: 62548
# [approx] BFS 2910/3128, remaining not-done vertices: 62548
# [approx] BFS 2920/3128, remaining not-done vertices: 62548
# [approx] BFS 2930/3128, remaining not-done vertices: 62548
# [approx] BFS 2940/3128, remaining not-done vertices: 62548
# [approx] BFS 2950/3128, remaining not-done vertices: 62547
# [approx] BFS 2960/3128, remaining not-done vertices: 62547
# [approx] BFS 2970/3128, remaining not-done vertices: 62547
# [approx] BFS 2980/3128, remaining not-done vertices: 62547
# [approx] BFS 2990/3128, remaining not-done vertices: 62547
# [approx] BFS 3000/3128, remaining not-done vertices: 62546
# [approx] BFS 3010/3128, remaining not-done vertices: 62546
# [approx] BFS 3020/3128, remaining not-done vertices: 62546
# [approx] BFS 3030/3128, remaining not-done vertices: 62546
# [approx] BFS 3040/3128, remaining not-done vertices: 62546
# [approx] BFS 3050/3128, remaining not-done vertices: 62546
# [approx] BFS 3060/3128, remaining not-done vertices: 62546
# [approx] BFS 3070/3128, remaining not-done vertices: 62546
# [approx] BFS 3080/3128, remaining not-done vertices: 62546
# [approx] BFS 3090/3128, remaining not-done vertices: 62546
# [approx] BFS 3100/3128, remaining not-done vertices: 62545
# [approx] BFS 3110/3128, remaining not-done vertices: 62544
# [approx] BFS 3120/3128, remaining not-done vertices: 62544
# [approx] BFS 3128/3128, remaining not-done vertices: 62544
# [approx] finished in 269.80s, BFS_used=3128
# [P2P-Gnutella31 approx] c=5, cutoff=n/20, BFS used = 3128, avg samples per node = 3127.80

# %% [markdown]
# Degree-based sampling

# %%
approx_p2p_deg, k_used_p2p_deg, bfs_used_p2p_deg = approx_bc_algorithm1_degree_based(
    G_p2p,
    c=c_val,
    cutoff_factor=cutoff_factor,
    seed=seed,
)

print(
    f"[P2P-Gnutella31 approx] c={c_val}, cutoff=n/{cutoff_factor}, "
    f"BFS used = {bfs_used_p2p_deg}, "
    f"avg samples per node = {np.mean(list(k_used_p2p_deg.values())):.2f}"
)
# Out:
# [approx-alpha-degree] max 3128 BFS runs, c=5, alpha=1.0
# [approx-alpha-degree] BFS 10/3128, remaining=62561
# [approx-alpha-degree] BFS 20/3128, remaining=62561
# [approx-alpha-degree] BFS 30/3128, remaining=62561
# [approx-alpha-degree] BFS 40/3128, remaining=62561
# [approx-alpha-degree] BFS 50/3128, remaining=62561
# [approx-alpha-degree] BFS 60/3128, remaining=62561
# [approx-alpha-degree] BFS 70/3128, remaining=62561
# [approx-alpha-degree] BFS 80/3128, remaining=62561
# [approx-alpha-degree] BFS 90/3128, remaining=62561
# [approx-alpha-degree] BFS 100/3128, remaining=62561
# [approx-alpha-degree] BFS 2260/3128, remaining=62557
# [approx-alpha-degree] BFS 2270/3128, remaining=62557
# [approx-alpha-degree] BFS 2280/3128, remaining=62557
# [approx-alpha-degree] BFS 2290/3128, remaining=62557
# [approx-alpha-degree] BFS 2300/3128, remaining=62556
# [approx-alpha-degree] BFS 2310/3128, remaining=62556
# [approx-alpha-degree] BFS 2320/3128, remaining=62556
# [approx-alpha-degree] BFS 2330/3128, remaining=62556
# [approx-alpha-degree] BFS 2340/3128, remaining=62556
# [approx-alpha-degree] BFS 2350/3128, remaining=62556
# [approx-alpha-degree] BFS 2360/3128, remaining=62556
# [approx-alpha-degree] BFS 2370/3128, remaining=62556
# [approx-alpha-degree] BFS 2380/3128, remaining=62556
# [approx-alpha-degree] BFS 2390/3128, remaining=62556
# [approx-alpha-degree] BFS 2400/3128, remaining=62556
# [approx-alpha-degree] BFS 2410/3128, remaining=62556
# [approx-alpha-degree] BFS 2420/3128, remaining=62556
# [approx-alpha-degree] BFS 2430/3128, remaining=62556
# [approx-alpha-degree] BFS 2440/3128, remaining=62556
# [approx-alpha-degree] BFS 2450/3128, remaining=62556
# [approx-alpha-degree] BFS 2460/3128, remaining=62556
# [approx-alpha-degree] BFS 2470/3128, remaining=62555
# [approx-alpha-degree] BFS 2480/3128, remaining=62555
# [approx-alpha-degree] BFS 2490/3128, remaining=62555
# [approx-alpha-degree] BFS 2500/3128, remaining=62555
# [approx-alpha-degree] BFS 2510/3128, remaining=62555
# [approx-alpha-degree] BFS 2520/3128, remaining=62555
# [approx-alpha-degree] BFS 2530/3128, remaining=62555
# [approx-alpha-degree] BFS 2540/3128, remaining=62555
# [approx-alpha-degree] BFS 2550/3128, remaining=62555
# [approx-alpha-degree] BFS 2560/3128, remaining=62555
# [approx-alpha-degree] BFS 2570/3128, remaining=62555
# [approx-alpha-degree] BFS 2580/3128, remaining=62555
# [approx-alpha-degree] BFS 2590/3128, remaining=62555
# [approx-alpha-degree] BFS 2600/3128, remaining=62555
# [approx-alpha-degree] BFS 2610/3128, remaining=62555
# [approx-alpha-degree] BFS 2620/3128, remaining=62555
# [approx-alpha-degree] BFS 2630/3128, remaining=62555
# [approx-alpha-degree] BFS 2640/3128, remaining=62555
# [approx-alpha-degree] BFS 2650/3128, remaining=62555
# [approx-alpha-degree] BFS 2660/3128, remaining=62555
# [approx-alpha-degree] BFS 2670/3128, remaining=62555
# [approx-alpha-degree] BFS 2680/3128, remaining=62555
# [approx-alpha-degree] BFS 2690/3128, remaining=62555
# [approx-alpha-degree] BFS 2700/3128, remaining=62555
# [approx-alpha-degree] BFS 2710/3128, remaining=62555
# [approx-alpha-degree] BFS 2720/3128, remaining=62555
# [approx-alpha-degree] BFS 2730/3128, remaining=62555
# [approx-alpha-degree] BFS 2740/3128, remaining=62555
# [approx-alpha-degree] BFS 2750/3128, remaining=62555
# [approx-alpha-degree] BFS 2760/3128, remaining=62555
# [approx-alpha-degree] BFS 2770/3128, remaining=62555
# [approx-alpha-degree] BFS 2780/3128, remaining=62555
# [approx-alpha-degree] BFS 2790/3128, remaining=62555
# [approx-alpha-degree] BFS 2800/3128, remaining=62555
# [approx-alpha-degree] BFS 2810/3128, remaining=62555
# [approx-alpha-degree] BFS 2820/3128, remaining=62555
# [approx-alpha-degree] BFS 2830/3128, remaining=62555
# [approx-alpha-degree] BFS 2840/3128, remaining=62554
# [approx-alpha-degree] BFS 2850/3128, remaining=62554
# [approx-alpha-degree] BFS 2860/3128, remaining=62554
# [approx-alpha-degree] BFS 2870/3128, remaining=62554
# [approx-alpha-degree] BFS 2880/3128, remaining=62554
# [approx-alpha-degree] BFS 2890/3128, remaining=62554
# [approx-alpha-degree] BFS 2900/3128, remaining=62554
# [approx-alpha-degree] BFS 2910/3128, remaining=62554
# [approx-alpha-degree] BFS 2920/3128, remaining=62554
# [approx-alpha-degree] BFS 2930/3128, remaining=62554
# [approx-alpha-degree] BFS 2940/3128, remaining=62554
# [approx-alpha-degree] BFS 2950/3128, remaining=62554
# [approx-alpha-degree] BFS 2960/3128, remaining=62553
# [approx-alpha-degree] BFS 2970/3128, remaining=62553
# [approx-alpha-degree] BFS 2980/3128, remaining=62553
# [approx-alpha-degree] BFS 2990/3128, remaining=62553
# [approx-alpha-degree] BFS 3000/3128, remaining=62553
# [approx-alpha-degree] BFS 3010/3128, remaining=62553
# [approx-alpha-degree] BFS 3020/3128, remaining=62552
# [approx-alpha-degree] BFS 3030/3128, remaining=62552
# [approx-alpha-degree] BFS 3040/3128, remaining=62552
# [approx-alpha-degree] BFS 3050/3128, remaining=62552
# [approx-alpha-degree] BFS 3060/3128, remaining=62552
# [approx-alpha-degree] BFS 3070/3128, remaining=62552
# [approx-alpha-degree] BFS 3080/3128, remaining=62552
# [approx-alpha-degree] BFS 3090/3128, remaining=62552
# [approx-alpha-degree] BFS 3100/3128, remaining=62552
# [approx-alpha-degree] BFS 3110/3128, remaining=62552
# [approx-alpha-degree] BFS 3120/3128, remaining=62552
# [approx-alpha-degree] BFS 3128/3128, remaining=62552
# [approx-alpha-degree] finished in 363.66s
# [P2P-Gnutella31 approx] c=5, cutoff=n/20, BFS used = 3128, avg samples per node = 3127.85

# %% [markdown]
# degree-based sampling without IPW

# %%
approx_p2p_deg_no, k_used_p2p_deg_no, bfs_used_p2p_deg_no = approx_bc_algorithm1_degree_based_no_ipw(
    G_p2p, c=c_val, cutoff_factor=cutoff_factor, seed=seed, alpha=1.0
)
# Out:
# [approx-degree-NO-IPW] max 3128 BFS runs, c=5, alpha=1.0
# [approx-degree-NO-IPW] finished in 356.57s

# %% [markdown]
# Exact (Brandes)

# %%
# Exact Brandes O(nm) 
t0 = perf_counter()
exact_p2p = nx.betweenness_centrality(G_p2p, normalized=False)
t1 = perf_counter()
print(f"[P2P-Gnutella31 exact] finished in {t1 - t0:.2f}s")
# Out:
# [P2P-Gnutella31 exact] finished in 2424.96s

# %% [markdown]
# Fig 1 BC Distribution

# %%
plot_fig1_four_methods(
    exact_bc = exact_p2p,
    approx_rand = approx_p2p,
    approx_deg_ipw = approx_p2p_deg,
    approx_deg_no_ipw = approx_p2p_deg_no,
    title_suffix = "P2P-Gnutella31"
)

# %% [markdown]
# Fig 2 Approximate BC Error

# %%
plot_bc_error_three_methods(
    exact_bc = exact_p2p,
    approx_rand = approx_p2p,
    approx_deg_ipw = approx_p2p_deg,
    approx_deg_no_ipw = approx_p2p_deg_no,
    top_k = top_k,
    title = f"P2P-Gnutella31: Top-{top_k} Error Comparison"
)

# %% [markdown]
# Fig 3 Sampling Percentage

# %%
plot_bfs_percentages_three_methods(
    G_p2p,
    exact_p2p,
    k_rand = k_used_p2p,
    k_deg_ipw = k_used_p2p_deg,
    k_deg_no_ipw = k_used_p2p_deg_no,
    top_k = top_k,
    title = f"P2P-Gnutella31: Sampling Efficiency"
)

# %% [markdown]
# Compute top k error

# %%
avg_err_rand_p2p = compute_top_k_error(exact_p2p, approx_p2p, k=top_k)
avg_err_ipw_p2p  = compute_top_k_error(exact_p2p, approx_p2p_deg, k=top_k)
avg_err_no_p2p   = compute_top_k_error(exact_p2p, approx_p2p_deg_no, k=top_k)


ov_rand_p2p = compute_top_k_overlap(exact_p2p, approx_p2p, k=top_k)
ov_ipw_p2p  = compute_top_k_overlap(exact_p2p, approx_p2p_deg, k=top_k)
ov_no_p2p   = compute_top_k_overlap(exact_p2p, approx_p2p_deg_no, k=top_k)

print(f"{'Method':<25} | {'Average Error':<10} | {'Overlap %':<10}")
print("-" * 55)
print(f"{'Adaptive Random':<25} | {avg_err_rand_p2p:6.2f}%    | {ov_rand_p2p:6.2f}%")
print(f"{'Degree (With IPW)':<25} | {avg_err_ipw_p2p:6.2f}%    | {ov_ipw_p2p:6.2f}%")
print(f"{'Degree (No IPW)':<25} | {avg_err_no_p2p:6.2f}%    | {ov_no_p2p:6.2f}%")
print("-" * 55)
# Out:
# Method                    | Average Error | Overlap %
# -------------------------------------------------------
# Adaptive Random           |   9.22%    |  70.00%
# Degree (With IPW)         |   6.68%    |  76.67%
# Degree (No IPW)           | 177.36%    |  80.00%
# -------------------------------------------------------

# %% [markdown]
# ## 3. Email enron (new) -> directed
#
# https://snap.stanford.edu/data/email-Enron.html

# %%
enron_path = "../data/real-world-new/email-Enron_directed.txt"  
G_enron = load_graph(enron_path, directed=True, use_giant_component=True)
n_enron = G_enron.number_of_nodes()
print("Email-Enron:", n_enron, G_enron.number_of_edges())
# Out:
# [load] full graph from ../data/real-world-new/email-Enron_directed.txt: n=36692, m=367662
# [load] use giant WCC: n=33696, m=361622
# Email-Enron: 33696 361622

# %% [markdown]
# Random sampling

# %%
approx_enron, k_used_enron, bfs_used_enron = approx_bc_algorithm1_random(
    G_enron,
    c=c_val,
    cutoff_factor=cutoff_factor,
    seed=seed,
)

print(
    f"[Email-Enron approx] c={c_val}, cutoff=n/{cutoff_factor}, "
    f"BFS used = {bfs_used_enron}, "
    f"avg samples per node = {np.mean(list(k_used_enron.values())):.2f}"
)
# Out:
# [approx] adaptive + cutoff: max 1684 BFS runs (n/20), c=5
# [approx] BFS 1630/1684, remaining not-done vertices: 33527
# [approx] BFS 1640/1684, remaining not-done vertices: 33525
# [approx] BFS 1650/1684, remaining not-done vertices: 33524
# [approx] BFS 1660/1684, remaining not-done vertices: 33524
# [approx] BFS 1670/1684, remaining not-done vertices: 33524
# [approx] BFS 1680/1684, remaining not-done vertices: 33524
# [approx] BFS 1684/1684, remaining not-done vertices: 33524
# [approx] finished in 179.40s, BFS_used=1684
# [Email-Enron approx] c=5, cutoff=n/20, BFS used = 1684, avg samples per node = 1679.40

# %% [markdown]
# Degree-based Sampling

# %%
approx_enron_deg, k_used_enron_deg, bfs_used_enron_deg = approx_bc_algorithm1_degree_based(
    G_enron,
    c=c_val,
    cutoff_factor=cutoff_factor,
    seed=seed,
)

print(
    f"[Email-Enron approx] c={c_val}, cutoff=n/{cutoff_factor}, "
    f"BFS used = {bfs_used_enron_deg}, "
    f"avg samples per node = {np.mean(list(k_used_enron_deg.values())):.2f}"
)
# Out:
# [approx-alpha-degree] max 1684 BFS runs, c=5, alpha=1.0
# [approx-alpha-degree] BFS 10/1684, remaining=33695
# [approx-alpha-degree] BFS 20/1684, remaining=33695
# [approx-alpha-degree] BFS 30/1684, remaining=33692
# [approx-alpha-degree] BFS 40/1684, remaining=33691
# [approx-alpha-degree] BFS 50/1684, remaining=33691
# [approx-alpha-degree] BFS 60/1684, remaining=33690
# [approx-alpha-degree] BFS 70/1684, remaining=33690
# [approx-alpha-degree] BFS 80/1684, remaining=33688
# [approx-alpha-degree] BFS 90/1684, remaining=33686
# [approx-alpha-degree] BFS 100/1684, remaining=33685
# [approx-alpha-degree] BFS 110/1684, remaining=33684
# [approx-alpha-degree] BFS 120/1684, remaining=33684
# [approx-alpha-degree] BFS 130/1684, remaining=33683
# [approx-alpha-degree] BFS 140/1684, remaining=33681
# [approx-alpha-degree] BFS 150/1684, remaining=33681
# [approx-alpha-degree] BFS 160/1684, remaining=33678
# [approx-alpha-degree] BFS 170/1684, remaining=33677
# [approx-alpha-degree] BFS 180/1684, remaining=33676
# [approx-alpha-degree] BFS 190/1684, remaining=33673
# [approx-alpha-degree] BFS 200/1684, remaining=33672
# [approx-alpha-degree] BFS 210/1684, remaining=33671
# [approx-alpha-degree] BFS 220/1684, remaining=33668
# [approx-alpha-degree] BFS 230/1684, remaining=33665
# [approx-alpha-degree] BFS 240/1684, remaining=33664
# [approx-alpha-degree] BFS 250/1684, remaining=33663
# [approx-alpha-degree] BFS 260/1684, remaining=33657
# [approx-alpha-degree] BFS 270/1684, remaining=33655
# [approx-alpha-degree] BFS 280/1684, remaining=33655
# [approx-alpha-degree] BFS 290/1684, remaining=33655
# [approx-alpha-degree] BFS 300/1684, remaining=33654
# [approx-alpha-degree] BFS 310/1684, remaining=33654
# [approx-alpha-degree] BFS 320/1684, remaining=33653
# [approx-alpha-degree] BFS 330/1684, remaining=33648
# [approx-alpha-degree] BFS 340/1684, remaining=33648
# [approx-alpha-degree] BFS 350/1684, remaining=33648
# [approx-alpha-degree] BFS 360/1684, remaining=33647
# [approx-alpha-degree] BFS 1450/1684, remaining=33527
# [approx-alpha-degree] BFS 1460/1684, remaining=33527
# [approx-alpha-degree] BFS 1470/1684, remaining=33527
# [approx-alpha-degree] BFS 1480/1684, remaining=33526
# [approx-alpha-degree] BFS 1490/1684, remaining=33526
# [approx-alpha-degree] BFS 1500/1684, remaining=33526
# [approx-alpha-degree] BFS 1510/1684, remaining=33525
# [approx-alpha-degree] BFS 1520/1684, remaining=33524
# [approx-alpha-degree] BFS 1530/1684, remaining=33524
# [approx-alpha-degree] BFS 1540/1684, remaining=33524
# [approx-alpha-degree] BFS 1550/1684, remaining=33523
# [approx-alpha-degree] BFS 1560/1684, remaining=33520
# [approx-alpha-degree] BFS 1570/1684, remaining=33520
# [approx-alpha-degree] BFS 1580/1684, remaining=33517
# [approx-alpha-degree] BFS 1590/1684, remaining=33517
# [approx-alpha-degree] BFS 1600/1684, remaining=33516
# [approx-alpha-degree] BFS 1610/1684, remaining=33514
# [approx-alpha-degree] BFS 1620/1684, remaining=33514
# [approx-alpha-degree] BFS 1630/1684, remaining=33514
# [approx-alpha-degree] BFS 1640/1684, remaining=33512
# [approx-alpha-degree] BFS 1650/1684, remaining=33512
# [approx-alpha-degree] BFS 1660/1684, remaining=33509
# [approx-alpha-degree] BFS 1670/1684, remaining=33508
# [approx-alpha-degree] BFS 1680/1684, remaining=33508
# [approx-alpha-degree] BFS 1684/1684, remaining=33506
# [approx-alpha-degree] finished in 187.48s
# [Email-Enron approx] c=5, cutoff=n/20, BFS used = 1684, avg samples per node = 1678.88

# %% [markdown]
# degree-based without IPW

# %%
approx_enron_deg_no, k_used_enron_deg_no, bfs_used_enron_deg_no = approx_bc_algorithm1_degree_based_no_ipw(
    G_enron, c=c_val, cutoff_factor=cutoff_factor, seed=seed, alpha=1.0
)
# Out:
# [approx-degree-NO-IPW] max 1684 BFS runs, c=5, alpha=1.0
# [approx-degree-NO-IPW] finished in 179.99s

# %% [markdown]
# Exact (Brandes)

# %%
# Exact Brandes O(nm) 
t0 = perf_counter()
exact_enron = nx.betweenness_centrality(G_enron, normalized=False)
t1 = perf_counter()
print(f"[Email-Enron exact] finished in {t1 - t0:.2f}s")
# Out:
# [Email-Enron exact] finished in 3230.79s

# %% [markdown]
# Fig 1 BC Distribution

# %%
plot_fig1_four_methods(
    exact_bc = exact_enron,
    approx_rand = approx_enron,
    approx_deg_ipw = approx_enron_deg,
    approx_deg_no_ipw = approx_enron_deg_no,
    title_suffix = "Email-Enron"
)

# %% [markdown]
# Fig 2 Approximate BC Error

# %%
plot_bc_error_three_methods(
    exact_bc = exact_enron,
    approx_rand = approx_enron,
    approx_deg_ipw = approx_enron_deg,
    approx_deg_no_ipw = approx_enron_deg_no,
    top_k = top_k,
    title = f"Email-Enron: Top-{top_k} Error Comparison"
)

# %% [markdown]
# Fig 3 Sampling Percentage

# %%
plot_bfs_percentages_three_methods(
    G_enron,
    exact_enron,
    k_rand = k_used_enron,
    k_deg_ipw = k_used_enron_deg,
    k_deg_no_ipw = k_used_enron_deg_no,
    top_k = top_k,
    title = f"Email-Enron: Sampling Efficiency"
)

# %% [markdown]
# Compute top k error

# %%
avg_err_rand_enron = compute_top_k_error(exact_enron, approx_enron, k=top_k)
avg_err_ipw_enron  = compute_top_k_error(exact_enron, approx_enron_deg, k=top_k)
avg_err_no_enron   = compute_top_k_error(exact_enron, approx_enron_deg_no, k=top_k)


ov_rand_enron = compute_top_k_overlap(exact_enron, approx_enron, k=top_k)
ov_ipw_enron  = compute_top_k_overlap(exact_enron, approx_enron_deg, k=top_k)
ov_no_enron   = compute_top_k_overlap(exact_enron, approx_enron_deg_no, k=top_k)

print(f"{'Method':<25} | {'Average Error':<10} | {'Overlap %':<10}")
print("-" * 55)
print(f"{'Adaptive Random':<25} | {avg_err_rand_enron:6.2f}%    | {ov_rand_enron:6.2f}%")
print(f"{'Degree (With IPW)':<25} | {avg_err_ipw_enron:6.2f}%    | {ov_ipw_enron:6.2f}%")
print(f"{'Degree (No IPW)':<25} | {avg_err_no_enron:6.2f}%    | {ov_no_enron:6.2f}%")
print("-" * 55)
# Out:
# Method                    | Average Error | Overlap %
# -------------------------------------------------------
# Adaptive Random           |  32.02%    |  86.67%
# Degree (With IPW)         |  90.46%    |  43.33%
# Degree (No IPW)           |  21.56%    |  93.33%
# -------------------------------------------------------

# %% [markdown]
# ## 4. Facebook Large Page-Page Network (new) -> undirected
# https://snap.stanford.edu/data/facebook-large-page-page-network.html

# %%
path = "../data/real-world-new/musae_facebook_edges.csv"
G_fb = load_csv_edge_list(path, directed=False)

print(G_fb.number_of_nodes(), G_fb.number_of_edges())
# Out:
# Facebook CSV graph: n=22470, m=171002
# 22470 171002

# %% [markdown]
# Random sampling

# %%
approx_fb, k_used_fb, bfs_used_fb = approx_bc_algorithm1_random(
    G_fb,
    c=c_val,
    cutoff_factor=cutoff_factor,
    seed=seed,
)

print(
    f"[Facebook approx] c={c_val}, cutoff=n/{cutoff_factor}, "
    f"BFS used = {bfs_used_fb}, "
    f"avg samples per node = {np.mean(list(k_used_fb.values())):.2f}"
)
# Out:
# [approx] adaptive + cutoff: max 1123 BFS runs (n/20), c=5
# [approx] BFS 10/1123, remaining not-done vertices: 22470
# [approx] BFS 20/1123, remaining not-done vertices: 22470
# [approx] BFS 30/1123, remaining not-done vertices: 22470
# [approx] BFS 40/1123, remaining not-done vertices: 22470
# [approx] BFS 50/1123, remaining not-done vertices: 22470
# [approx] BFS 60/1123, remaining not-done vertices: 22469
# [approx] BFS 70/1123, remaining not-done vertices: 22468
# [approx] BFS 80/1123, remaining not-done vertices: 22468
# [approx] BFS 90/1123, remaining not-done vertices: 22468
# [approx] BFS 100/1123, remaining not-done vertices: 22468
# [approx] BFS 110/1123, remaining not-done vertices: 22468
# [approx] BFS 120/1123, remaining not-done vertices: 22466
# [approx] BFS 130/1123, remaining not-done vertices: 22466
# [approx] BFS 140/1123, remaining not-done vertices: 22466
# [approx] BFS 150/1123, remaining not-done vertices: 22466
# [approx] BFS 160/1123, remaining not-done vertices: 22465
# [approx] BFS 720/1123, remaining not-done vertices: 22423
# [approx] BFS 730/1123, remaining not-done vertices: 22423
# [approx] BFS 740/1123, remaining not-done vertices: 22422
# [approx] BFS 750/1123, remaining not-done vertices: 22421
# [approx] BFS 760/1123, remaining not-done vertices: 22421
# [approx] BFS 770/1123, remaining not-done vertices: 22418
# [approx] BFS 780/1123, remaining not-done vertices: 22415
# [approx] BFS 790/1123, remaining not-done vertices: 22412
# [approx] BFS 800/1123, remaining not-done vertices: 22411
# [approx] BFS 810/1123, remaining not-done vertices: 22411
# [approx] BFS 820/1123, remaining not-done vertices: 22411
# [approx] BFS 830/1123, remaining not-done vertices: 22407
# [approx] BFS 840/1123, remaining not-done vertices: 22405
# [approx] BFS 850/1123, remaining not-done vertices: 22405
# [approx] BFS 860/1123, remaining not-done vertices: 22403
# [approx] BFS 870/1123, remaining not-done vertices: 22400
# [approx] BFS 880/1123, remaining not-done vertices: 22399
# [approx] BFS 890/1123, remaining not-done vertices: 22397
# [approx] BFS 900/1123, remaining not-done vertices: 22397
# [approx] BFS 910/1123, remaining not-done vertices: 22396
# [approx] BFS 920/1123, remaining not-done vertices: 22395
# [approx] BFS 930/1123, remaining not-done vertices: 22394
# [approx] BFS 940/1123, remaining not-done vertices: 22394
# [approx] BFS 950/1123, remaining not-done vertices: 22393
# [approx] BFS 960/1123, remaining not-done vertices: 22393
# [approx] BFS 970/1123, remaining not-done vertices: 22390
# [approx] BFS 980/1123, remaining not-done vertices: 22389
# [approx] BFS 990/1123, remaining not-done vertices: 22386
# [approx] BFS 1000/1123, remaining not-done vertices: 22386
# [approx] BFS 1010/1123, remaining not-done vertices: 22386
# [approx] BFS 1020/1123, remaining not-done vertices: 22385
# [approx] BFS 1030/1123, remaining not-done vertices: 22383
# [approx] BFS 1040/1123, remaining not-done vertices: 22381
# [approx] BFS 1050/1123, remaining not-done vertices: 22380
# [approx] BFS 1060/1123, remaining not-done vertices: 22378
# [approx] BFS 1070/1123, remaining not-done vertices: 22378
# [approx] BFS 1080/1123, remaining not-done vertices: 22377
# [approx] BFS 1090/1123, remaining not-done vertices: 22377
# [approx] BFS 1100/1123, remaining not-done vertices: 22373
# [approx] BFS 1110/1123, remaining not-done vertices: 22370
# [approx] BFS 1120/1123, remaining not-done vertices: 22369
# [approx] BFS 1123/1123, remaining not-done vertices: 22369
# [approx] finished in 114.75s, BFS_used=1123
# [Facebook approx] c=5, cutoff=n/20, BFS used = 1123, avg samples per node = 1121.04

# %% [markdown]
# Degree-based Sampling

# %%
approx_fb_deg, k_used_fb_deg, bfs_used_fb_deg = approx_bc_algorithm1_degree_based(
    G_fb,
    c=c_val,
    cutoff_factor=cutoff_factor,
    seed=seed,
)

print(
    f"[Facebook approx] c={c_val}, cutoff=n/{cutoff_factor}, "
    f"BFS used = {bfs_used_fb_deg}, "
    f"avg samples per node = {np.mean(list(k_used_fb_deg.values())):.2f}"
)
# Out:
# [approx-alpha-degree] max 1123 BFS runs, c=5, alpha=1.0
# [approx-alpha-degree] BFS 10/1123, remaining=22470
# [approx-alpha-degree] BFS 20/1123, remaining=22470
# [approx-alpha-degree] BFS 30/1123, remaining=22470
# [approx-alpha-degree] BFS 40/1123, remaining=22467
# [approx-alpha-degree] BFS 50/1123, remaining=22467
# [approx-alpha-degree] BFS 60/1123, remaining=22466
# [approx-alpha-degree] BFS 70/1123, remaining=22462
# [approx-alpha-degree] BFS 80/1123, remaining=22462
# [approx-alpha-degree] BFS 90/1123, remaining=22460
# [approx-alpha-degree] BFS 100/1123, remaining=22459
# [approx-alpha-degree] BFS 110/1123, remaining=22458
# [approx-alpha-degree] BFS 120/1123, remaining=22458
# [approx-alpha-degree] BFS 130/1123, remaining=22458
# [approx-alpha-degree] BFS 140/1123, remaining=22456
# [approx-alpha-degree] BFS 150/1123, remaining=22453
# [approx-alpha-degree] BFS 160/1123, remaining=22451
# [approx-alpha-degree] BFS 170/1123, remaining=22451
# [approx-alpha-degree] BFS 180/1123, remaining=22451
# [approx-alpha-degree] BFS 190/1123, remaining=22451
# [approx-alpha-degree] BFS 200/1123, remaining=22448
# [approx-alpha-degree] BFS 210/1123, remaining=22448
# [approx-alpha-degree] BFS 220/1123, remaining=22446
# [approx-alpha-degree] BFS 230/1123, remaining=22446
# [approx-alpha-degree] BFS 240/1123, remaining=22446
# [approx-alpha-degree] BFS 250/1123, remaining=22446
# [approx-alpha-degree] BFS 260/1123, remaining=22444
# [approx-alpha-degree] BFS 270/1123, remaining=22440
# [approx-alpha-degree] BFS 280/1123, remaining=22437
# [approx-alpha-degree] BFS 290/1123, remaining=22437
# [approx-alpha-degree] BFS 300/1123, remaining=22436
# [approx-alpha-degree] BFS 310/1123, remaining=22434
# [approx-alpha-degree] BFS 320/1123, remaining=22428
# [approx-alpha-degree] BFS 330/1123, remaining=22427
# [approx-alpha-degree] BFS 340/1123, remaining=22424
# [approx-alpha-degree] BFS 350/1123, remaining=22424
# [approx-alpha-degree] BFS 360/1123, remaining=22424
# [approx-alpha-degree] BFS 370/1123, remaining=22424
# [approx-alpha-degree] BFS 380/1123, remaining=22422
# [approx-alpha-degree] BFS 390/1123, remaining=22420
# [approx-alpha-degree] BFS 400/1123, remaining=22420
# [approx-alpha-degree] BFS 410/1123, remaining=22420
# [approx-alpha-degree] BFS 420/1123, remaining=22418
# [approx-alpha-degree] BFS 430/1123, remaining=22417
# [approx-alpha-degree] BFS 440/1123, remaining=22417
# [approx-alpha-degree] BFS 450/1123, remaining=22416
# [approx-alpha-degree] BFS 460/1123, remaining=22416
# [approx-alpha-degree] BFS 470/1123, remaining=22416
# [approx-alpha-degree] BFS 480/1123, remaining=22416
# [approx-alpha-degree] BFS 490/1123, remaining=22414
# [approx-alpha-degree] BFS 500/1123, remaining=22414
# [approx-alpha-degree] BFS 510/1123, remaining=22414
# [approx-alpha-degree] BFS 520/1123, remaining=22412
# [approx-alpha-degree] BFS 530/1123, remaining=22409
# [approx-alpha-degree] BFS 540/1123, remaining=22409
# [approx-alpha-degree] BFS 550/1123, remaining=22407
# [approx-alpha-degree] BFS 560/1123, remaining=22405
# [approx-alpha-degree] BFS 570/1123, remaining=22404
# [approx-alpha-degree] BFS 580/1123, remaining=22404
# [approx-alpha-degree] BFS 590/1123, remaining=22403
# [approx-alpha-degree] BFS 600/1123, remaining=22403
# [approx-alpha-degree] BFS 610/1123, remaining=22403
# [approx-alpha-degree] BFS 620/1123, remaining=22403
# [approx-alpha-degree] BFS 630/1123, remaining=22403
# [approx-alpha-degree] BFS 640/1123, remaining=22400
# [approx-alpha-degree] BFS 650/1123, remaining=22399
# [approx-alpha-degree] BFS 660/1123, remaining=22399
# [approx-alpha-degree] BFS 670/1123, remaining=22397
# [approx-alpha-degree] BFS 680/1123, remaining=22394
# [approx-alpha-degree] BFS 690/1123, remaining=22392
# [approx-alpha-degree] BFS 700/1123, remaining=22392
# [approx-alpha-degree] BFS 710/1123, remaining=22392
# [approx-alpha-degree] BFS 720/1123, remaining=22390
# [approx-alpha-degree] BFS 730/1123, remaining=22386
# [approx-alpha-degree] BFS 740/1123, remaining=22385
# [approx-alpha-degree] BFS 750/1123, remaining=22383
# [approx-alpha-degree] BFS 760/1123, remaining=22381
# [approx-alpha-degree] BFS 770/1123, remaining=22381
# [approx-alpha-degree] BFS 780/1123, remaining=22380
# [approx-alpha-degree] BFS 790/1123, remaining=22379
# [approx-alpha-degree] BFS 800/1123, remaining=22379
# [approx-alpha-degree] BFS 810/1123, remaining=22378
# [approx-alpha-degree] BFS 820/1123, remaining=22378
# [approx-alpha-degree] BFS 830/1123, remaining=22378
# [approx-alpha-degree] BFS 840/1123, remaining=22377
# [approx-alpha-degree] BFS 850/1123, remaining=22375
# [approx-alpha-degree] BFS 860/1123, remaining=22374
# [approx-alpha-degree] BFS 870/1123, remaining=22374
# [approx-alpha-degree] BFS 880/1123, remaining=22373
# [approx-alpha-degree] BFS 890/1123, remaining=22371
# [approx-alpha-degree] BFS 900/1123, remaining=22370
# [approx-alpha-degree] BFS 910/1123, remaining=22364
# [approx-alpha-degree] BFS 920/1123, remaining=22363
# [approx-alpha-degree] BFS 930/1123, remaining=22361
# [approx-alpha-degree] BFS 940/1123, remaining=22356
# [approx-alpha-degree] BFS 950/1123, remaining=22351
# [approx-alpha-degree] BFS 960/1123, remaining=22345
# [approx-alpha-degree] BFS 970/1123, remaining=22344
# [approx-alpha-degree] BFS 980/1123, remaining=22342
# [approx-alpha-degree] BFS 990/1123, remaining=22342
# [approx-alpha-degree] BFS 1000/1123, remaining=22342
# [approx-alpha-degree] BFS 1010/1123, remaining=22342
# [approx-alpha-degree] BFS 1020/1123, remaining=22342
# [approx-alpha-degree] BFS 1030/1123, remaining=22340
# [approx-alpha-degree] BFS 1040/1123, remaining=22339
# [approx-alpha-degree] BFS 1050/1123, remaining=22339
# [approx-alpha-degree] BFS 1060/1123, remaining=22336
# [approx-alpha-degree] BFS 1070/1123, remaining=22334
# [approx-alpha-degree] BFS 1080/1123, remaining=22332
# [approx-alpha-degree] BFS 1090/1123, remaining=22329
# [approx-alpha-degree] BFS 1100/1123, remaining=22327
# [approx-alpha-degree] BFS 1110/1123, remaining=22324
# [approx-alpha-degree] BFS 1120/1123, remaining=22323
# [approx-alpha-degree] BFS 1123/1123, remaining=22319
# [approx-alpha-degree] finished in 122.96s
# [Facebook approx] c=5, cutoff=n/20, BFS used = 1123, avg samples per node = 1119.64

# %% [markdown]
# degree-based without IPW

# %%
approx_fb_deg_no, k_used_fb_deg_no, bfs_used_fb_deg_no = approx_bc_algorithm1_degree_based_no_ipw(
    G_fb, c=c_val, cutoff_factor=cutoff_factor, seed=seed, alpha=1.0
)
# Out:
# [approx-degree-NO-IPW] max 1123 BFS runs, c=5, alpha=1.0
# [approx-degree-NO-IPW] finished in 110.18s

# %% [markdown]
# Exact (Brandes)

# %%
# Exact Brandes O(nm) 
t0 = perf_counter()
exact_fb = nx.betweenness_centrality(G_fb, normalized=False)
t1 = perf_counter()
print(f"[Facebook Large Page-Page Network exact] finished in {t1 - t0:.2f}s")
# Out:
# [Facebook Large Page-Page Network exact] finished in 2277.11s

# %% [markdown]
# Fig 1 BC Distribution

# %%
plot_fig1_four_methods(
    exact_bc = exact_fb,
    approx_rand = approx_fb,
    approx_deg_ipw = approx_fb_deg,
    approx_deg_no_ipw = approx_fb_deg_no,
    title_suffix = "Facebook"
)

# %% [markdown]
# Fig 2 Approximate BC Error

# %%
plot_bc_error_three_methods(
    exact_bc = exact_fb,
    approx_rand = approx_fb,
    approx_deg_ipw = approx_fb_deg,
    approx_deg_no_ipw = approx_fb_deg_no,
    top_k = top_k,
    title = f"Facebook: Top-{top_k} Error Comparison"
)

# %% [markdown]
# Fig 3 Sampling Percentage

# %%
plot_bfs_percentages_three_methods(
    G_fb,
    exact_fb,
    k_rand = k_used_fb,
    k_deg_ipw = k_used_fb_deg,
    k_deg_no_ipw = k_used_fb_deg_no,
    top_k = top_k,
    title = f"Facebook: Sampling Efficiency"
)

# %% [markdown]
# Compute top k error

# %%
avg_err_rand_fb = compute_top_k_error(exact_fb, approx_fb, k=top_k)
avg_err_ipw_fb  = compute_top_k_error(exact_fb, approx_fb_deg, k=top_k)
avg_err_no_fb   = compute_top_k_error(exact_fb, approx_fb_deg_no, k=top_k)


ov_rand_fb = compute_top_k_overlap(exact_fb, approx_fb, k=top_k)
ov_ipw_fb  = compute_top_k_overlap(exact_fb, approx_fb_deg, k=top_k)
ov_no_fb   = compute_top_k_overlap(exact_fb, approx_fb_deg_no, k=top_k)

print(f"{'Method':<25} | {'Average Error':<10} | {'Overlap %':<10}")
print("-" * 55)
print(f"{'Adaptive Random':<25} | {avg_err_rand_fb:6.2f}%    | {ov_rand_fb:6.2f}%")
print(f"{'Degree (With IPW)':<25} | {avg_err_ipw_fb:6.2f}%    | {ov_ipw_fb:6.2f}%")
print(f"{'Degree (No IPW)':<25} | {avg_err_no_fb:6.2f}%    | {ov_no_fb:6.2f}%")
print("-" * 55)
# Out:
# Method                    | Average Error | Overlap %
# -------------------------------------------------------
# Adaptive Random           |  15.23%    |  90.00%
# Degree (With IPW)         |  16.91%    |  16.67%
# Degree (No IPW)           |  17.24%    |  80.00%
# -------------------------------------------------------

# %% [markdown]
# ## 5. Twitter dataset (new) -> directed
# https://snap.stanford.edu/data/ego-Twitter.html

# %%
path = "../data/real-world-new/twitter_combined.txt"
G_twitter= load_graph(path, directed=True)
print(G_twitter.number_of_nodes(), G_twitter.number_of_edges())
# Out:
# [load] full graph from ../data/real-world-new/twitter_combined.txt: n=81306, m=1768149
# 81306 1768149

# %% [markdown]
# Random Sampling

# %%
approx_twitter, k_used_twitter, bfs_used_twitter = approx_bc_algorithm1_random(
    G_twitter,
    c=c_val,
    cutoff_factor=cutoff_factor,
    seed=42,
)

print(
    f"[Twitter approx] c={c_val}, cutoff=n/{cutoff_factor}, "
    f"BFS used = {bfs_used_twitter}, "
    f"avg samples per node = {np.mean(list(k_used_twitter.values())):.2f}"
)
# Out:
# [approx] adaptive + cutoff: max 4065 BFS runs (n/20), c=5
# [approx] BFS 10/4065, remaining not-done vertices: 81306
# [approx] BFS 20/4065, remaining not-done vertices: 81306
# [approx] BFS 30/4065, remaining not-done vertices: 81306
# [approx] BFS 40/4065, remaining not-done vertices: 81305
# [approx] BFS 50/4065, remaining not-done vertices: 81305
# [approx] BFS 60/4065, remaining not-done vertices: 81305
# [approx] BFS 70/4065, remaining not-done vertices: 81304
# [approx] BFS 80/4065, remaining not-done vertices: 81304
# [approx] BFS 90/4065, remaining not-done vertices: 81303
# [approx] BFS 100/4065, remaining not-done vertices: 81303
# [approx] BFS 110/4065, remaining not-done vertices: 81303
# [approx] BFS 120/4065, remaining not-done vertices: 81303
# [approx] BFS 130/4065, remaining not-done vertices: 81302
# [approx] BFS 140/4065, remaining not-done vertices: 81302
# [approx] BFS 150/4065, remaining not-done vertices: 81302
# [approx] BFS 160/4065, remaining not-done vertices: 81302
# [approx] BFS 170/4065, remaining not-done vertices: 81301
# [approx] BFS 180/4065, remaining not-done vertices: 81301
# [approx] BFS 190/4065, remaining not-done vertices: 81300
# [approx] BFS 200/4065, remaining not-done vertices: 81300
# [approx] BFS 210/4065, remaining not-done vertices: 81299
# [approx] BFS 220/4065, remaining not-done vertices: 81299
# [approx] BFS 230/4065, remaining not-done vertices: 81298
# [approx] BFS 240/4065, remaining not-done vertices: 81297
# [approx] BFS 250/4065, remaining not-done vertices: 81297
# [approx] BFS 260/4065, remaining not-done vertices: 81297
# [approx] BFS 270/4065, remaining not-done vertices: 81296
# [approx] BFS 280/4065, remaining not-done vertices: 81293
# [approx] BFS 290/4065, remaining not-done vertices: 81291
# [approx] BFS 300/4065, remaining not-done vertices: 81291
# [approx] BFS 310/4065, remaining not-done vertices: 81291
# [approx] BFS 320/4065, remaining not-done vertices: 81291
# [approx] BFS 330/4065, remaining not-done vertices: 81290
# [approx] BFS 340/4065, remaining not-done vertices: 81290
# [approx] BFS 350/4065, remaining not-done vertices: 81288
# [approx] BFS 360/4065, remaining not-done vertices: 81288
# [approx] BFS 370/4065, remaining not-done vertices: 81288
# [approx] BFS 380/4065, remaining not-done vertices: 81287
# [approx] BFS 940/4065, remaining not-done vertices: 81254
# [approx] BFS 950/4065, remaining not-done vertices: 81252
# [approx] BFS 960/4065, remaining not-done vertices: 81251
# [approx] BFS 970/4065, remaining not-done vertices: 81250
# [approx] BFS 980/4065, remaining not-done vertices: 81250
# [approx] BFS 990/4065, remaining not-done vertices: 81250
# [approx] BFS 1000/4065, remaining not-done vertices: 81250
# [approx] BFS 1010/4065, remaining not-done vertices: 81250
# [approx] BFS 1020/4065, remaining not-done vertices: 81250
# [approx] BFS 1030/4065, remaining not-done vertices: 81250
# [approx] BFS 1040/4065, remaining not-done vertices: 81249
# [approx] BFS 1050/4065, remaining not-done vertices: 81249
# [approx] BFS 1060/4065, remaining not-done vertices: 81249
# [approx] BFS 1070/4065, remaining not-done vertices: 81248
# [approx] BFS 1080/4065, remaining not-done vertices: 81247
# [approx] BFS 1090/4065, remaining not-done vertices: 81243
# [approx] BFS 1100/4065, remaining not-done vertices: 81243
# [approx] BFS 1110/4065, remaining not-done vertices: 81242
# [approx] BFS 1120/4065, remaining not-done vertices: 81240
# [approx] BFS 1130/4065, remaining not-done vertices: 81240
# [approx] BFS 1140/4065, remaining not-done vertices: 81240
# [approx] BFS 1150/4065, remaining not-done vertices: 81236
# [approx] BFS 1160/4065, remaining not-done vertices: 81236
# [approx] BFS 1170/4065, remaining not-done vertices: 81233
# [approx] BFS 1180/4065, remaining not-done vertices: 81233
# [approx] BFS 1190/4065, remaining not-done vertices: 81231
# [approx] BFS 1200/4065, remaining not-done vertices: 81231
# [approx] BFS 1210/4065, remaining not-done vertices: 81228
# [approx] BFS 1220/4065, remaining not-done vertices: 81227
# [approx] BFS 1230/4065, remaining not-done vertices: 81223
# [approx] BFS 1240/4065, remaining not-done vertices: 81222
# [approx] BFS 1250/4065, remaining not-done vertices: 81222
# [approx] BFS 1260/4065, remaining not-done vertices: 81220
# [approx] BFS 1270/4065, remaining not-done vertices: 81220
# [approx] BFS 1280/4065, remaining not-done vertices: 81218
# [approx] BFS 1290/4065, remaining not-done vertices: 81217
# [approx] BFS 1300/4065, remaining not-done vertices: 81217
# [approx] BFS 1310/4065, remaining not-done vertices: 81216
# [approx] BFS 1320/4065, remaining not-done vertices: 81216
# [approx] BFS 1330/4065, remaining not-done vertices: 81215
# [approx] BFS 1340/4065, remaining not-done vertices: 81209
# [approx] BFS 1350/4065, remaining not-done vertices: 81209
# [approx] BFS 1360/4065, remaining not-done vertices: 81205
# [approx] BFS 1370/4065, remaining not-done vertices: 81205
# [approx] BFS 1380/4065, remaining not-done vertices: 81204
# [approx] BFS 1390/4065, remaining not-done vertices: 81204
# [approx] BFS 1400/4065, remaining not-done vertices: 81203
# [approx] BFS 1410/4065, remaining not-done vertices: 81202
# [approx] BFS 1420/4065, remaining not-done vertices: 81201
# [approx] BFS 1430/4065, remaining not-done vertices: 81200
# [approx] BFS 1440/4065, remaining not-done vertices: 81200
# [approx] BFS 1450/4065, remaining not-done vertices: 81199
# [approx] BFS 1460/4065, remaining not-done vertices: 81199
# [approx] BFS 3590/4065, remaining not-done vertices: 80991
# [approx] BFS 3600/4065, remaining not-done vertices: 80989
# [approx] BFS 3610/4065, remaining not-done vertices: 80988
# [approx] BFS 3620/4065, remaining not-done vertices: 80987
# [approx] BFS 3630/4065, remaining not-done vertices: 80987
# [approx] BFS 3640/4065, remaining not-done vertices: 80984
# [approx] BFS 3650/4065, remaining not-done vertices: 80981
# [approx] BFS 3660/4065, remaining not-done vertices: 80978
# [approx] BFS 3670/4065, remaining not-done vertices: 80977
# [approx] BFS 3680/4065, remaining not-done vertices: 80977
# [approx] BFS 3690/4065, remaining not-done vertices: 80977
# [approx] BFS 3700/4065, remaining not-done vertices: 80977
# [approx] BFS 3710/4065, remaining not-done vertices: 80976
# [approx] BFS 3720/4065, remaining not-done vertices: 80971
# [approx] BFS 3730/4065, remaining not-done vertices: 80970
# [approx] BFS 3740/4065, remaining not-done vertices: 80969
# [approx] BFS 3750/4065, remaining not-done vertices: 80969
# [approx] BFS 3760/4065, remaining not-done vertices: 80966
# [approx] BFS 3770/4065, remaining not-done vertices: 80965
# [approx] BFS 3780/4065, remaining not-done vertices: 80962
# [approx] BFS 3790/4065, remaining not-done vertices: 80962
# [approx] BFS 3800/4065, remaining not-done vertices: 80962
# [approx] BFS 3810/4065, remaining not-done vertices: 80961
# [approx] BFS 3820/4065, remaining not-done vertices: 80958
# [approx] BFS 3830/4065, remaining not-done vertices: 80957
# [approx] BFS 3840/4065, remaining not-done vertices: 80953
# [approx] BFS 3850/4065, remaining not-done vertices: 80951
# [approx] BFS 3860/4065, remaining not-done vertices: 80951
# [approx] BFS 3870/4065, remaining not-done vertices: 80951
# [approx] BFS 3880/4065, remaining not-done vertices: 80951
# [approx] BFS 3890/4065, remaining not-done vertices: 80951
# [approx] BFS 3900/4065, remaining not-done vertices: 80951
# [approx] BFS 3910/4065, remaining not-done vertices: 80949
# [approx] BFS 3920/4065, remaining not-done vertices: 80949
# [approx] BFS 3930/4065, remaining not-done vertices: 80948
# [approx] BFS 3940/4065, remaining not-done vertices: 80946
# [approx] BFS 3950/4065, remaining not-done vertices: 80944
# [approx] BFS 3960/4065, remaining not-done vertices: 80941
# [approx] BFS 3970/4065, remaining not-done vertices: 80936
# [approx] BFS 3980/4065, remaining not-done vertices: 80935
# [approx] BFS 3990/4065, remaining not-done vertices: 80934
# [approx] BFS 4000/4065, remaining not-done vertices: 80932
# [approx] BFS 4010/4065, remaining not-done vertices: 80932
# [approx] BFS 4020/4065, remaining not-done vertices: 80932
# [approx] BFS 4030/4065, remaining not-done vertices: 80930
# [approx] BFS 4040/4065, remaining not-done vertices: 80928
# [approx] BFS 4050/4065, remaining not-done vertices: 80927
# [approx] BFS 4060/4065, remaining not-done vertices: 80924
# [approx] BFS 4065/4065, remaining not-done vertices: 80923
# [approx] finished in 1832.81s, BFS_used=4065
# [Twitter approx] c=5, cutoff=n/20, BFS used = 4065, avg samples per node = 4056.78

# %% [markdown]
# Degree-based sampling

# %%
approx_twitter_deg, k_used_twitter_deg, bfs_used_twitter_deg = approx_bc_algorithm1_degree_based(
    G_twitter,
    c=c_val,
    cutoff_factor=cutoff_factor,
    seed=seed,
)

print(
    f"[Twitter approx] c={c_val}, cutoff=n/{cutoff_factor}, "
    f"BFS used = {bfs_used_twitter_deg}, "
    f"avg samples per node = {np.mean(list(k_used_twitter_deg.values())):.2f}"
)
# Out:
# [approx-alpha-degree] max 4065 BFS runs, c=5, alpha=1.0
# [approx-alpha-degree] BFS 10/4065, remaining=81306
# [approx-alpha-degree] BFS 20/4065, remaining=81306
# [approx-alpha-degree] BFS 30/4065, remaining=81306
# [approx-alpha-degree] BFS 40/4065, remaining=81304
# [approx-alpha-degree] BFS 50/4065, remaining=81303
# [approx-alpha-degree] BFS 60/4065, remaining=81303
# [approx-alpha-degree] BFS 70/4065, remaining=81303
# [approx-alpha-degree] BFS 80/4065, remaining=81303
# [approx-alpha-degree] BFS 90/4065, remaining=81303
# [approx-alpha-degree] BFS 100/4065, remaining=81302
# [approx-alpha-degree] BFS 110/4065, remaining=81302
# [approx-alpha-degree] BFS 120/4065, remaining=81302
# [approx-alpha-degree] BFS 130/4065, remaining=81302
# [approx-alpha-degree] BFS 140/4065, remaining=81297
# [approx-alpha-degree] BFS 150/4065, remaining=81297
# [approx-alpha-degree] BFS 160/4065, remaining=81297
# [approx-alpha-degree] BFS 170/4065, remaining=81297
# [approx-alpha-degree] BFS 180/4065, remaining=81296
# [approx-alpha-degree] BFS 190/4065, remaining=81296
# [approx-alpha-degree] BFS 200/4065, remaining=81296
# [approx-alpha-degree] BFS 210/4065, remaining=81290
# [approx-alpha-degree] BFS 220/4065, remaining=81287
# [approx-alpha-degree] BFS 230/4065, remaining=81286
# [approx-alpha-degree] BFS 240/4065, remaining=81285
# [approx-alpha-degree] BFS 250/4065, remaining=81285
# [approx-alpha-degree] BFS 260/4065, remaining=81285
# [approx-alpha-degree] BFS 270/4065, remaining=81284
# [approx-alpha-degree] BFS 280/4065, remaining=81284
# [approx-alpha-degree] BFS 290/4065, remaining=81284
# [approx-alpha-degree] BFS 300/4065, remaining=81284
# [approx-alpha-degree] BFS 310/4065, remaining=81284
# [approx-alpha-degree] BFS 320/4065, remaining=81284
# [approx-alpha-degree] BFS 330/4065, remaining=81284
# [approx-alpha-degree] BFS 340/4065, remaining=81284
# [approx-alpha-degree] BFS 350/4065, remaining=81283
# [approx-alpha-degree] BFS 360/4065, remaining=81281
# [approx-alpha-degree] BFS 370/4065, remaining=81280
# [approx-alpha-degree] BFS 380/4065, remaining=81280
# [approx-alpha-degree] BFS 390/4065, remaining=81278
# [approx-alpha-degree] BFS 400/4065, remaining=81276
# [approx-alpha-degree] BFS 410/4065, remaining=81276
# [approx-alpha-degree] BFS 420/4065, remaining=81276
# [approx-alpha-degree] BFS 430/4065, remaining=81276
# [approx-alpha-degree] BFS 440/4065, remaining=81276
# [approx-alpha-degree] BFS 450/4065, remaining=81274
# [approx-alpha-degree] BFS 460/4065, remaining=81273
# [approx-alpha-degree] BFS 3670/4065, remaining=80933
# [approx-alpha-degree] BFS 3680/4065, remaining=80931
# [approx-alpha-degree] BFS 3690/4065, remaining=80931
# [approx-alpha-degree] BFS 3700/4065, remaining=80930
# [approx-alpha-degree] BFS 3710/4065, remaining=80928
# [approx-alpha-degree] BFS 3720/4065, remaining=80928
# [approx-alpha-degree] BFS 3730/4065, remaining=80925
# [approx-alpha-degree] BFS 3740/4065, remaining=80925
# [approx-alpha-degree] BFS 3750/4065, remaining=80924
# [approx-alpha-degree] BFS 3760/4065, remaining=80923
# [approx-alpha-degree] BFS 3770/4065, remaining=80923
# [approx-alpha-degree] BFS 3780/4065, remaining=80919
# [approx-alpha-degree] BFS 3790/4065, remaining=80919
# [approx-alpha-degree] BFS 3800/4065, remaining=80918
# [approx-alpha-degree] BFS 3810/4065, remaining=80917
# [approx-alpha-degree] BFS 3820/4065, remaining=80917
# [approx-alpha-degree] BFS 3830/4065, remaining=80916
# [approx-alpha-degree] BFS 3840/4065, remaining=80914
# [approx-alpha-degree] BFS 3850/4065, remaining=80912
# [approx-alpha-degree] BFS 3860/4065, remaining=80912
# [approx-alpha-degree] BFS 3870/4065, remaining=80912
# [approx-alpha-degree] BFS 3880/4065, remaining=80912
# [approx-alpha-degree] BFS 3890/4065, remaining=80904
# [approx-alpha-degree] BFS 3900/4065, remaining=80904
# [approx-alpha-degree] BFS 3910/4065, remaining=80902
# [approx-alpha-degree] BFS 3920/4065, remaining=80900
# [approx-alpha-degree] BFS 3930/4065, remaining=80898
# [approx-alpha-degree] BFS 3940/4065, remaining=80897
# [approx-alpha-degree] BFS 3950/4065, remaining=80895
# [approx-alpha-degree] BFS 3960/4065, remaining=80895
# [approx-alpha-degree] BFS 3970/4065, remaining=80895
# [approx-alpha-degree] BFS 3980/4065, remaining=80894
# [approx-alpha-degree] BFS 3990/4065, remaining=80894
# [approx-alpha-degree] BFS 4000/4065, remaining=80889
# [approx-alpha-degree] BFS 4010/4065, remaining=80889
# [approx-alpha-degree] BFS 4020/4065, remaining=80887
# [approx-alpha-degree] BFS 4030/4065, remaining=80883
# [approx-alpha-degree] BFS 4040/4065, remaining=80881
# [approx-alpha-degree] BFS 4050/4065, remaining=80878
# [approx-alpha-degree] BFS 4060/4065, remaining=80877
# [approx-alpha-degree] BFS 4065/4065, remaining=80876
# [approx-alpha-degree] finished in 2130.98s
# [Twitter approx] c=5, cutoff=n/20, BFS used = 4065, avg samples per node = 4055.93

# %% [markdown]
# degree-based sampling without IPW

# %%
approx_twitter_deg_no, k_used_twitter_deg_no, bfs_used_twitter_deg_no = approx_bc_algorithm1_degree_based_no_ipw(
    G_twitter, c=c_val, cutoff_factor=cutoff_factor, seed=seed, alpha=1.0
)
# Out:
# [approx-degree-NO-IPW] max 4065 BFS runs, c=5, alpha=1.0
# [approx-degree-NO-IPW] finished in 2086.84s

# %% [markdown]
# Exact (Brandes)

# %%
# Exact Brandes O(nm) 
t0 = perf_counter()
exact_twitter = nx.betweenness_centrality(G_twitter, normalized=False)
t1 = perf_counter()
print(f"[Twitter exact] finished in {t1 - t0:.2f}s")
# Out:
# [Twitter exact] finished in 33207.48s

# %% [markdown]
# Fig 1 BC Distribution

# %%
plot_fig1_four_methods(
    exact_bc = exact_twitter,
    approx_rand = approx_twitter,
    approx_deg_ipw = approx_twitter_deg,
    approx_deg_no_ipw = approx_twitter_deg_no,
    title_suffix = "Twitter"
)

# %% [markdown]
# Fig 2 Approximate BC Error

# %%
plot_bc_error_three_methods(
    exact_bc = exact_twitter,
    approx_rand = approx_twitter,
    approx_deg_ipw = approx_twitter_deg,
    approx_deg_no_ipw = approx_twitter_deg_no,
    top_k = top_k,
    title = f"Twitter: Top-{top_k} Error Comparison"
)

# %% [markdown]
# Fig 3 Sampling Percentage

# %%
plot_bfs_percentages_three_methods(
    G_twitter,
    exact_twitter,
    k_rand = k_used_twitter,
    k_deg_ipw = k_used_twitter_deg,
    k_deg_no_ipw = k_used_twitter_deg_no,
    top_k = top_k,
    title = f"Twitter: Sampling Percentage for Top-{top_k} High-BC Nodes"
)

# %% [markdown]
# Compute top k error

# %%
avg_err_rand_twitter = compute_top_k_error(exact_twitter, approx_twitter, k=top_k)
avg_err_ipw_twitter  = compute_top_k_error(exact_twitter, approx_twitter_deg, k=top_k)
avg_err_no_twitter   = compute_top_k_error(exact_twitter, approx_twitter_deg_no, k=top_k)


ov_rand_twitter = compute_top_k_overlap(exact_twitter, approx_twitter, k=top_k)
ov_ipw_twitter  = compute_top_k_overlap(exact_twitter, approx_twitter_deg, k=top_k)
ov_no_twitter   = compute_top_k_overlap(exact_twitter, approx_twitter_deg_no, k=top_k)

print(f"{'Method':<25} | {'Average Error':<10} | {'Overlap %':<10}")
print("-" * 55)
print(f"{'Adaptive Random':<25} | {avg_err_rand_twitter:6.2f}%    | {ov_rand_twitter:6.2f}%")
print(f"{'Degree (With IPW)':<25} | {avg_err_ipw_twitter:6.2f}%    | {ov_ipw_twitter:6.2f}%")
print(f"{'Degree (No IPW)':<25} | {avg_err_no_twitter:6.2f}%    | {ov_no_twitter:6.2f}%")
print("-" * 55)
# Out:
# Method                    | Average Error | Overlap %
# -------------------------------------------------------
# Adaptive Random           |  15.32%    |  83.33%
# Degree (With IPW)         |  32.10%    |  53.33%
# Degree (No IPW)           |  19.97%    |  86.67%
# -------------------------------------------------------

# %% [markdown]
# ## 6. Bio-HS-CX (new) -> weighted, undirected
# https://networkrepository.com/bio-HS-CX.php

# %% [markdown]
# #### Weighted algorithm (Based on Dijkstra's algorithm)

# %% [markdown]
# Since the bio network is weighted, we use Dijkstra's algorithm instead of BFS to travese the graph

# %%
import heapq

def brandes_single_source_dependencies_weighted(G, s, weight='weight'):
    """
    Fixed Dijkstra-based Brandes using epsilon for float comparison.
    """
    # 1. Initialization
    S = [] 
    P = {v: [] for v in G}
    
    # standard Dijkstra structures
    sigma = dict.fromkeys(G, 0.0)
    dist = dict.fromkeys(G, float('inf'))
    
    sigma[s] = 1.0
    dist[s] = 0
    
    Q = [(0, s)]
    
    # Epsilon for floating-point comparison
    EPSILON = 1e-9 
    
    while Q:
        d, v = heapq.heappop(Q)
        
        # Stale entry check (Dijkstra lazy deletion)
        # If the popped distance d is greater than the known shortest distance dist[v] (beyond epsilon), skip
        if d > dist[v] + EPSILON:
            continue
            
        S.append(v)
        
        for w in G[v]:
            edge_wt = G[v][w].get(weight, 1.0)
            new_dist = dist[v] + edge_wt
            
            # Case 1: Found a strictly shorter path
            # (dist[w] > new_dist) becomes:
            if dist[w] > new_dist + EPSILON:
                dist[w] = new_dist
                sigma[w] = sigma[v]
                P[w] = [v]
                heapq.heappush(Q, (dist[w], w))
                
            # Case 2: Found an equal length path (within epsilon)
            # (dist[w] == new_dist) becomes:
            elif abs(dist[w] - new_dist) < EPSILON:
                sigma[w] += sigma[v]
                P[w].append(v)
                
    # 2. Dependency accumulation (Back-propagation)
    delta = dict.fromkeys(G, 0.0)
    while S:
        w = S.pop()
        for v in P[w]:
            if sigma[w] != 0:
                # Brandes recursion
                delta[v] += (sigma[v] / sigma[w]) * (1 + delta[w])
                
    return delta

# %% [markdown]
# Then we define a slightly different random-based sampling algorithm to account for the weighted graph

# %%
def approx_bc_algorithm1_random_weighted(G, c=5.0, cutoff_factor=20, seed=0, weight='weight'):
    rng = random.Random(seed)
    nodes = list(G.nodes())
    n = len(nodes)

    max_sssp = max(1, n // cutoff_factor)
    print(f"[approx-weighted] adaptive + cutoff: max {max_sssp} SSSP runs, c={c}")

    S = {v: 0.0 for v in nodes}
    k = {v: 0   for v in nodes}
    done = {v: False for v in nodes}
    remaining = n

    sssp_used = 0
    t0 = perf_counter()

    while sssp_used < max_sssp and remaining > 0:
        s = rng.choice(nodes)
        
        delta = brandes_single_source_dependencies_weighted(G, s, weight=weight)
        sssp_used += 1

        for v in nodes:
            if done[v] or v == s:
                continue
            S[v] += delta[v]
            k[v] += 1
            if S[v] >= c * n:
                done[v] = True
                remaining -= 1

        if sssp_used % 10 == 0 or sssp_used == max_sssp:
            print(f"[approx-weighted] SSSP {sssp_used}/{max_sssp}, remaining: {remaining}")

    t1 = perf_counter()
    print(f"[approx-weighted] finished in {t1 - t0:.2f}s, SSSP_used={sssp_used}")
    bc_hat = {
        v: (n * S[v] / k[v]) if k[v] > 0 else 0.0
        for v in nodes
    }
    
    # Correction for undirected graphs
    if not G.is_directed():
        for v in bc_hat:
            bc_hat[v] /= 2.0

    return bc_hat, k, sssp_used

# %% [markdown]
# And the same for degree-based

# %%
def approx_bc_algorithm1_degree_based_weighted(G, c=5.0, cutoff_factor=20, alpha=1.0, seed=0, weight='weight'):
    rng = random.Random(seed)
    nodes = list(G.nodes())
    n = len(nodes)

    degs = np.array([G.degree(v) for v in nodes], dtype=float)
    if alpha == 0:
        weights = np.ones(n, dtype=float)
    else:
        weights = np.power(degs, alpha)
    
    if np.all(weights == 0):
        probs = np.ones(n, dtype=float) / n
    else:
        probs = weights / weights.sum()

    cum_probs = np.cumsum(probs)
    
    def sample_source_and_prob():
        x = rng.random()
        idx = np.searchsorted(cum_probs, x, side="left")
        if idx >= n: idx = n - 1
        return nodes[idx], probs[idx]

    max_sssp = max(1, n // cutoff_factor)
    print(f"[approx-weighted-degree] max {max_sssp} SSSP runs, c={c}, alpha={alpha}")

    # compute final BC estimates using S_weighted
    S_weighted = {v: 0.0 for v in nodes}  
    S_raw      = {v: 0.0 for v in nodes}  
    
    k = {v: 0   for v in nodes}
    done = {v: False for v in nodes}
    remaining = n
    sssp_used = 0
    t0 = perf_counter()

    while sssp_used < max_sssp and remaining > 0:
        s, p_s = sample_source_and_prob()
        
        delta = brandes_single_source_dependencies_weighted(G, s, weight=weight)
        sssp_used += 1
        
        # Bias Correction factor
        scale_factor = 1.0 / (n * p_s) if p_s > 0 else 0

        for v in nodes:
            if done[v] or v == s:
                continue
            
            # update both sums
            S_weighted[v] += delta[v] * scale_factor  
            S_raw[v]      += delta[v]                 
            
            k[v] += 1
            
            # stop condition based on S_raw
            if S_raw[v] >= c * n: 
                done[v] = True
                remaining -= 1

        if sssp_used % 10 == 0 or sssp_used == max_sssp:
             pass

    t1 = perf_counter()
    print(f"[approx-weighted-degree] finished in {t1 - t0:.2f}s, used {sssp_used} samples")

    # compute final BC estimates using S_weighted
    bc_hat = {
        v: (n * S_weighted[v] / k[v]) if k[v] > 0 else 0.0
        for v in nodes
    }

    if not G.is_directed():
        for v in bc_hat:
            bc_hat[v] /= 2.0

    return bc_hat, k, sssp_used

# %% [markdown]
# degree-based sampling withoug IPW on weighted dataset

# %%
def approx_bc_algorithm1_degree_based_weighted_no_ipw(G, c=5.0, cutoff_factor=20, alpha=1.0, seed=0, weight='weight'):

    rng = random.Random(seed)
    nodes = list(G.nodes())
    n = len(nodes)

    degs = np.array([G.degree(v) for v in nodes], dtype=float)
    if alpha == 0:
        weights = np.ones(n, dtype=float)
    else:
        weights = np.power(degs, alpha)
    
    if np.all(weights == 0):
        probs = np.ones(n, dtype=float) / n
    else:
        probs = weights / weights.sum()

    cum_probs = np.cumsum(probs)
    
    def sample_source():
        x = rng.random()
        idx = np.searchsorted(cum_probs, x, side="left")
        if idx >= n: idx = n - 1
        return nodes[idx]

    max_sssp = max(1, n // cutoff_factor)
    print(f"[approx-weighted-degree-NO-IPW] max {max_sssp} SSSP runs, c={c}, alpha={alpha}")

    S = {v: 0.0 for v in nodes}
    k = {v: 0   for v in nodes}
    done = {v: False for v in nodes}
    remaining = n
    sssp_used = 0
    t0 = perf_counter()

    while sssp_used < max_sssp and remaining > 0:
        s = sample_source()
        
        delta = brandes_single_source_dependencies_weighted(G, s, weight=weight)
        sssp_used += 1
        


        for v in nodes:
            if done[v] or v == s:
                continue
            
            S[v] += delta[v] 
            k[v] += 1
            
            if S[v] >= c * n: 
                done[v] = True
                remaining -= 1

        if sssp_used % 10 == 0 or sssp_used == max_sssp:
             # print(f"...") 
             pass

    t1 = perf_counter()
    print(f"[approx-weighted-degree-NO-IPW] finished in {t1 - t0:.2f}s, used {sssp_used} samples")

    bc_hat = {
        v: (n * S[v] / k[v]) if k[v] > 0 else 0.0
        for v in nodes
    }


    if not G.is_directed():
        for v in bc_hat:
            bc_hat[v] /= 2.0

    return bc_hat, k, sssp_used

# %% [markdown]
# #### Apply to the Bio dataset:

# %%
# 1. Load Weighted Graph
bio_path = "../data/real-world-new/bio-HS-CX_weighted_undirected.edges"

G_bio = nx.read_edgelist(
    bio_path, 
    nodetype=int, 
    data=(('weight', float),), 
    create_using=nx.Graph() # Undirected
)

# get the giant component
if not nx.is_connected(G_bio):
    gcc_nodes = max(nx.connected_components(G_bio), key=len)
    G_bio = G_bio.subgraph(gcc_nodes).copy()

n_bio = G_bio.number_of_nodes()
print(f"Bio-HS-CX: n={n_bio}, m={G_bio.number_of_edges()}")
# Out:
# Bio-HS-CX: n=4409, m=108816

# %% [markdown]
# Random sampling

# %%
# Run Weighted Random Approx
approx_bio, k_used_bio, sssp_used_bio = approx_bc_algorithm1_random_weighted(
    G_bio,
    c=c_val,
    cutoff_factor=cutoff_factor,
    seed=seed,
    weight='weight'
)

print(f"[Bio Weighted Random] SSSP used = {sssp_used_bio}, "
      f"avg samples = {np.mean(list(k_used_bio.values())):.2f}")
# Out:
# [approx-weighted] adaptive + cutoff: max 220 SSSP runs, c=5
# [approx-weighted] SSSP 10/220, remaining: 4409
# [approx-weighted] SSSP 20/220, remaining: 4409
# [approx-weighted] SSSP 30/220, remaining: 4409
# [approx-weighted] SSSP 40/220, remaining: 4409
# [approx-weighted] SSSP 50/220, remaining: 4409
# [approx-weighted] SSSP 60/220, remaining: 4409
# [approx-weighted] SSSP 70/220, remaining: 4409
# [approx-weighted] SSSP 80/220, remaining: 4409
# [approx-weighted] SSSP 90/220, remaining: 4409
# [approx-weighted] SSSP 100/220, remaining: 4409
# [approx-weighted] SSSP 110/220, remaining: 4409
# [approx-weighted] SSSP 120/220, remaining: 4409
# [approx-weighted] SSSP 130/220, remaining: 4409
# [approx-weighted] SSSP 140/220, remaining: 4409
# [approx-weighted] SSSP 150/220, remaining: 4409
# [approx-weighted] SSSP 160/220, remaining: 4409
# [approx-weighted] SSSP 170/220, remaining: 4409
# [approx-weighted] SSSP 180/220, remaining: 4409
# [approx-weighted] SSSP 190/220, remaining: 4409
# [approx-weighted] SSSP 200/220, remaining: 4409
# [approx-weighted] SSSP 210/220, remaining: 4409
# [approx-weighted] SSSP 220/220, remaining: 4409
# [approx-weighted] finished in 27.22s, SSSP_used=220
# [Bio Weighted Random] SSSP used = 220, avg samples = 219.95

# %% [markdown]
# Degree-based sampling

# %%
# Run Weighted Degree-based Approx
approx_bio_deg, k_used_bio_deg, sssp_used_bio_deg = approx_bc_algorithm1_degree_based_weighted(
    G_bio,
    c=c_val,
    cutoff_factor=cutoff_factor,
    seed=seed,
    weight='weight'
)

print(f"[Bio Weighted Degree] SSSP used = {sssp_used_bio_deg}, "
      f"avg samples = {np.mean(list(k_used_bio_deg.values())):.2f}")
# Out:
# [approx-weighted-degree] max 220 SSSP runs, c=5, alpha=1.0
# [approx-weighted-degree] finished in 26.99s, used 220 samples
# [Bio Weighted Degree] SSSP used = 220, avg samples = 219.95

# %% [markdown]
# degree-based sampling without IPW

# %%
approx_bio_deg_no, k_used_bio_deg_no, bfs_used_bio_deg_no = approx_bc_algorithm1_degree_based_weighted_no_ipw(
    G_bio, c=c_val, cutoff_factor=cutoff_factor, seed=seed, alpha=1.0, weight='weight'
)
# Out:
# [approx-weighted-degree-NO-IPW] max 220 SSSP runs, c=5, alpha=1.0
# [approx-weighted-degree-NO-IPW] finished in 25.69s, used 220 samples

# %% [markdown]
# Exact (Brandes)

# %%
#Exact Weighted Brandes 
print("Running Exact Weighted BC (NetworkX).")
t0 = perf_counter()
exact_bio = nx.betweenness_centrality(G_bio, normalized=False, weight='weight')
t1 = perf_counter()
print(f"[Bio Exact] finished in {t1 - t0:.2f}s")
# Out:
# Running Exact Weighted BC (NetworkX).
# [Bio Exact] finished in 371.27s

# %% [markdown]
# Fig 1 BC Distribution

# %%
plot_fig1_four_methods(
    exact_bc = exact_bio,
    approx_rand = approx_bio,
    approx_deg_ipw = approx_bio_deg,
    approx_deg_no_ipw = approx_bio_deg_no,
    title_suffix = "Bio-HS-CX (Weighted)"
)

# %% [markdown]
# Fig 2 Approximate BC Error

# %%
plot_bc_error_three_methods(
    exact_bc = exact_bio,
    approx_rand = approx_bio,
    approx_deg_ipw = approx_bio_deg,
    approx_deg_no_ipw = approx_bio_deg_no,
    top_k = top_k,
    title = f"Bio-HS-CX: Weighted BC Error for Top-{top_k}"
)

# %% [markdown]
# Fig 3 Sampling Percentage

# %%
plot_bfs_percentages_three_methods(
    G_bio,
    exact_bio,
    k_rand = k_used_bio,
    k_deg_ipw = k_used_bio_deg,
    k_deg_no_ipw = k_used_bio_deg_no,
    top_k = top_k,
    title = f"Bio-HS-CX: Sampling % for Top-{top_k} (Weighted)"
)

# %% [markdown]
# Compute top k error

# %%
avg_err_rand_bio = compute_top_k_error(exact_bio, approx_bio, k=top_k)
avg_err_ipw_bio  = compute_top_k_error(exact_bio, approx_bio_deg, k=top_k)
avg_err_no_bio   = compute_top_k_error(exact_bio, approx_bio_deg_no, k=top_k)


ov_rand_bio = compute_top_k_overlap(exact_bio, approx_bio, k=top_k)
ov_ipw_bio  = compute_top_k_overlap(exact_bio, approx_bio_deg, k=top_k)
ov_no_bio   = compute_top_k_overlap(exact_bio, approx_bio_deg_no, k=top_k)

print(f"{'Method':<25} | {'Average Error':<10} | {'Overlap %':<10}")
print("-" * 55)
print(f"{'Adaptive Random':<25} | {avg_err_rand_bio:6.2f}%    | {ov_rand_bio:6.2f}%")
print(f"{'Degree (With IPW)':<25} | {avg_err_ipw_bio:6.2f}%    | {ov_ipw_bio:6.2f}%")
print(f"{'Degree (No IPW)':<25} | {avg_err_no_bio:6.2f}%    | {ov_no_bio:6.2f}%")
print("-" * 55)
# Out:
# Method                    | Average Error | Overlap %
# -------------------------------------------------------
# Adaptive Random           |  23.06%    |  63.33%
# Degree (With IPW)         |  40.26%    |  30.00%
# Degree (No IPW)           |  27.30%    |  60.00%
# -------------------------------------------------------
